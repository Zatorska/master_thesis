# %% [markdown]
# # Wgrywanie bibliotek

# %% [markdown]
# Import necessary libraries

# %%
import csv
import glob
import os
from PIL import Image
import time
import pickle
import math
import numpy as np
import pandas as pd
import zipfile
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from tbats import TBATS
from pmdarima import auto_arima
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.statespace.sarimax import SARIMAX

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %% [markdown]
# # Ustawienia

# %% [markdown]
# Settings

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# Output folders to save files

# %%
# Get the path to the current folder where the notebook is located
current_folder = os.path.dirname(os.path.abspath("__file__"))

images_output_folder = os.path.join(current_folder, "../02_paper/out_figures/")
tables_output_folder = os.path.join(current_folder, "../02_paper/out_tables/")
models_output_folder = os.path.join(current_folder, "../../models/models")

# %% [markdown]
# # Wgranie danych
# * Get the path to the "data.zip" file
# * Unpacking the file
# * Uploading the CSV (both: **_data_** and **_data_dict_**)

# %%
# Get the path to the "data" folder inside the repository
data_folder = os.path.join(current_folder, "..", "00_data")

# Get the path to the "data.zip" file inside the "data" folder
data_zip_path = os.path.join(data_folder, "data.zip")

# Check if both entsoe_country_file and entsoe_country_dict_file exist in the target location
entsoe_country_file = os.path.join(data_folder, "entsoe_country.csv")
entsoe_country_dict_file = os.path.join(data_folder, "entsoe_country_dict.csv")

if not (os.path.exists(entsoe_country_file) and os.path.exists(entsoe_country_dict_file)):
    # Extract the data.zip file
    with zipfile.ZipFile(data_zip_path, 'r') as zip_ref:
        zip_ref.extractall(data_folder)
    
# Read the CSV files and create DataFrames
data = pd.read_csv(entsoe_country_file, sep=';')
data_dict = pd.read_csv(entsoe_country_dict_file, sep=',')

# %%
sample_data_tab_00 = data.dropna().head(5)
sample_data_tab_00 = sample_data_tab_00.rename(columns={
    'TotalLoad_Actual_MW': 'TotalLoad\_Actual\_MW',
    'TotalLoad_Forecast_MW': 'TotalLoad\_Forecast\_MW'
})
sample_data_tab_00['Variable'] = sample_data_tab_00['Variable'].replace({'BZN_AL': 'BZN\_AL'}, regex=True)
(sample_data_tab_00).style.hide(axis = 0).to_latex(os.path.join(tables_output_folder, "tab_00.tex"))

# %% [markdown]
# Liczba wierszy

# %%
data.shape[0]
# Out:
# 3811848

# %% [markdown]
# # Data preparation (part 1)

# %%
data = data.drop_duplicates()

# Country name mapping
data['CountryCode'] = data['Variable'].map(lambda x: x.lstrip('BZN_'))
data = pd.merge(data, data_dict, on="CountryCode")
data = data.drop(['Variable', 'CountryCode'], axis=1)

data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# %%
(data_dict).style.hide(axis = 0).to_latex(os.path.join(tables_output_folder, "tab_01.tex"))

# %%
# Select data only for Romania from 2021-01-31 00:15:00
romania_data = data[(data['Country'] == 'Romania') & (data['Timestamp'] >= '2021-01-31 00:15:00')]

# Create a column with full hours (rounded down to the nearest hour)
romania_data['Timestamp'] = romania_data['Timestamp'].dt.floor('H')

# Group the data by full hours and calculate the mean of four measurements
aggregated_romania_data = romania_data.groupby('Timestamp')['TotalLoad_Actual_MW'].mean().reset_index()
aggregated_romania_data["Country"] = "Romania"

# Select the indices of the original data for Romania that meet the conditions
indices_to_remove = data[(data['Country'] == 'Romania') & (data['Timestamp'] >= '2021-01-31 00:15:00')].index

# Remove the original data for Romania that meets the conditions
data = data.drop(indices_to_remove)
data = data.drop(columns=["TotalLoad_Forecast_MW"])

# Concatenate the updated data for Romania
data = pd.concat([data, aggregated_romania_data], ignore_index=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\3049440096.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   romania_data['Timestamp'] = romania_data['Timestamp'].dt.floor('H')

# %%
sample_data_tab_02 = data.dropna().head(5)
sample_data_tab_02['TotalLoad_Actual_MW'] = sample_data_tab_02['TotalLoad_Actual_MW'].apply(lambda x: '{:.2f}'.format(x))
sample_data_tab_02 = sample_data_tab_02.rename(columns={
    'TotalLoad_Actual_MW': 'TotalLoad\_Actual\_MW'
})
(sample_data_tab_02).style.hide(axis = 0).to_latex(os.path.join(tables_output_folder, "tab_02.tex"))

# %% [markdown]
# ## Analysis of missing data
#
# The assumption has been made that the present values of $0.00$ in the data also qualify as missing values.

# %% [markdown]
# Liczba wierszy po wstępnym przygotowaniu danych

# %%
data.shape[0]
# Out:
# 2161177

# %% [markdown]
# Liczba wierszy z NaN

# %%
data['TotalLoad_Actual_MW'].replace(0, np.nan, inplace=True)
data["TotalLoad_Actual_MW"].isna().sum()
# Out:
# 41902

# %%
nan_values_per_country = []

# Unique countries in the 'Country' column
countries = data['Country'].unique()

# Loop through each country
for country in countries:
    # Select rows only for the current country
    df_country = data[data['Country'] == country]
    
    # Number of all rows in the country
    num_rows = len(df_country)
    
    # Number of NaN in the 'TotalLoad_Actual_MW' column
    num_nan = df_country['TotalLoad_Actual_MW'].isna().sum()
    
    # Percentage of NaN for all rows in the country
    percent_nan = (num_nan / num_rows) * 100
    percent_nan = '{:.2f}'.format(percent_nan)
    
    # Add results to the list
    nan_values_per_country.append({
        'Country': country,
        'NumRows': num_rows,
        'NumNaN': num_nan,
        'PercentNaN': percent_nan
    })

# Create a DataFrame from the results
nan_values_per_country = pd.DataFrame(nan_values_per_country)

nan_values_per_country.style.hide(axis = 0).to_latex(os.path.join(tables_output_folder, "tab_03.tex"))

# %%
def find_missing_value_date_ranges(dataframe):
    dataframe['Timestamp'] = pd.to_datetime(dataframe['Timestamp'])

    # Creation the resulting DataFrame.
    result = []

    # Iteration over unique countries.
    for country in dataframe['Country'].unique():
        country_data = dataframe[dataframe["Country"] == country][["Timestamp", "TotalLoad_Actual_MW"]]  
        country_data['Timestamp'] = pd.to_datetime(country_data['Timestamp'])

        # Aggregation data to full days and sorting.
        agg_df = country_data.resample('D', on='Timestamp').sum().reset_index()

        for metric in ["TotalLoad_Actual_MW"]:  
            start_date = None
            end_date = None

            for index, row in agg_df.iterrows():
                if row[metric] == 0.00:
                    if start_date is None:
                        start_date = row['Timestamp']
                elif start_date is not None:
                    end_date = row['Timestamp']
                    number_of_days = (end_date - start_date).days + 1
                    result.append({'country': country, 'metric': metric, 'start_date': start_date, 'end_date': end_date, 'number_of_days': number_of_days})
                    start_date = None
                    end_date = None
            
            # Handling missing end_date - if we have reached the last record
            if end_date is None and start_date is not None:
                end_date = agg_df['Timestamp'].iloc[-1]
                number_of_days = (end_date - start_date).days + 1
                result.append({'country': country, 'metric': metric, 'start_date': start_date, 'end_date': end_date, 'number_of_days': number_of_days})

    missing_value_date_ranges = pd.DataFrame(result)
    missing_value_date_ranges = missing_value_date_ranges.sort_values(by=['country', 'metric']).reset_index(drop=True)

    missing_value_date_ranges.drop(columns=['metric'], inplace=True) 
    
    return missing_value_date_ranges

missing_value_date_ranges = find_missing_value_date_ranges(data)

column_mapping = {
    'country': 'Country',
    'start_date': 'Start Date',
    'end_date': 'End Date',
    'number_of_days': 'Number of Days'
}

missing_value_date_ranges.columns = [column_mapping[col] for col in missing_value_date_ranges.columns]
display(missing_value_date_ranges)
# Out:
#            Country Start Date   End Date  Number of Days
# 0          Austria 2017-12-30 2017-12-31               2
# 1          Croatia 2018-01-05 2018-01-06               2
# 2           Cyprus 2015-01-01 2016-09-21             630
# 3           Cyprus 2018-06-03 2018-06-07               5
# 4           Cyprus 2019-03-03 2019-03-04               2
# 5           Cyprus 2019-06-08 2019-07-23              46
# 6           Cyprus 2020-03-13 2020-04-05              24
# 7           Cyprus 2020-04-07 2020-04-09               3
# 8           Cyprus 2020-07-23 2020-07-27               5
# 9           Cyprus 2020-07-28 2020-08-04               8
# 10          Cyprus 2020-11-21 2020-11-23               3
# 11          Cyprus 2021-04-20 2021-04-22               3
# 12  Czech Republic 2016-11-11 2016-11-14               4
# 13         Denmark 2017-10-20 2017-10-21               2
# 14         Denmark 2018-07-25 2018-07-26               2
# 15          France 2015-04-25 2015-04-26               2
# 16          France 2015-11-18 2015-11-19               2
# 17         Ireland 2015-09-18 2015-09-19               2
# 18         Ireland 2016-04-12 2016-04-13               2
# 19       Lithuania 2015-01-03 2015-01-04               2
# 20       Lithuania 2015-01-19 2015-01-20               2
# 21       Lithuania 2016-03-04 2016-03-05               2
# 22       Lithuania 2017-12-30 2018-01-02               4
# 23      Luxembourg 2019-01-03 2019-01-04               2
# 24      Luxembourg 2019-01-31 2019-02-06               7
# 25         Romania 2015-01-01 2015-01-05               5
# 26         Romania 2018-05-22 2018-05-23               2
# 27         Romania 2021-08-07 2021-08-09               3
# 28        Slovenia 2018-03-19 2018-03-20               2
# 29           Spain 2015-04-14 2015-04-15               2
# 30          Sweden 2015-12-12 2015-12-13               2
# 31          Sweden 2019-01-15 2019-01-16               2

# %%
missing_value_date_ranges['Start Date'] = missing_value_date_ranges['Start Date'].dt.date
missing_value_date_ranges['End Date'] = missing_value_date_ranges['End Date'].dt.date

missing_value_date_ranges.style.hide(axis = 0).to_latex(os.path.join(tables_output_folder, "tab_04.tex"))

# %% [markdown]
# # Data preparation (part 2 - weekly aggregation)

# %%
data_prepared = data.set_index('Timestamp')

def remove_first_last(group):
    return group.iloc[1:-1]

# By default, in pandas, a week is defined as a calendar week starting from Monday and ending on Sunday.
# If a week spans across two years, it will be assigned to the year in which the majority of weekdays fall.
weekly_data = data_prepared.groupby('Country')[['TotalLoad_Actual_MW']].resample('W').sum().reset_index()
weekly_data = weekly_data.rename(columns={'Timestamp': 'Date'})
weekly_data = weekly_data.groupby('Country').apply(remove_first_last).reset_index(drop=True)

sample_data_tab_05 = weekly_data.head(5)
sample_data_tab_05['TotalLoad_Actual_MW'] = sample_data_tab_05['TotalLoad_Actual_MW'].apply(lambda x: '{:.2f}'.format(x))
sample_data_tab_05 = sample_data_tab_05.rename(columns={
    'TotalLoad_Actual_MW': 'TotalLoad\_Actual\_MW'
})
(sample_data_tab_05).style.hide(axis = 0).to_latex(os.path.join(tables_output_folder, "tab_05.tex"))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1758234336.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data_tab_05['TotalLoad_Actual_MW'] = sample_data_tab_05['TotalLoad_Actual_MW'].apply(lambda x: '{:.2f}'.format(x))

# %% [markdown]
# ### Plots
# ##### _TotalLoad_Actual_MW per country **before imputation**._

# %%
country_list = weekly_data['Country'].unique()

for country in country_list:
    electricity_consumption_per_country = weekly_data[weekly_data['Country'] == country].copy()
    electricity_consumption_per_country['Date'] = pd.to_datetime(electricity_consumption_per_country['Date'])
    electricity_consumption_per_country['TotalLoad_Actual_MW_normalized'].replace(0, np.nan, inplace=True)

    # Find the index of the first non-NaN value in the 'TotalLoad_Actual_MW' column
    first_non_nan_index = electricity_consumption_per_country['TotalLoad_Actual_MW_normalized'].first_valid_index()

    # Trim the DataFrame from that position
    if first_non_nan_index is not None:
        electricity_consumption_per_country = electricity_consumption_per_country.loc[first_non_nan_index:]
    
    plt.style.use('seaborn-v0_8')
    plt.rcParams['font.family'] = 'Times New Roman'
    
    plt.figure(figsize=(20, 5))
    plt.ylabel("Electricity Consumption (Terawatts)", fontsize=14)
    plt.title(f"Actual Electricity Consumption in Terawatts for Country: {country}", fontsize=16)
    
    formatter = ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(False)
    formatter.set_powerlimits((-6, 6))
    plt.gca().yaxis.set_major_formatter(formatter)
    
    plt.plot(electricity_consumption_per_country["Date"], electricity_consumption_per_country["TotalLoad_Actual_MW_normalized"], color='steelblue')
    
    plt.xlim(electricity_consumption_per_country["Date"].iloc[0], electricity_consumption_per_country["Date"].iloc[-1])
    
    ticks = plt.gca().get_yticks()
    tick_labels = [f'{int(tick) / 1000000:.1f}' for tick in ticks]
    plt.gca().yaxis.set_major_locator(ticker.FixedLocator(ticks))
    plt.gca().set_yticklabels(tick_labels)

    output_file_path = os.path.join(images_output_folder, f"actual_electricity_consumption_nor_{country}.png")
    if not os.path.exists(output_file_path):
        plt.savefig(output_file_path)
    
    plt.close()

# %% [markdown]
# ## Imputation
#
# Imputation was performed using a weighted average with a 7-day window.
#
# Currently, due to a significant amount of missing data for Cyprus, I am refraining from performing imputation for this country. This method is not efficient for Cyprus.

# %%
# Create a function for imputation
def impute_missing_values(row):
    if pd.isnull(row['TotalLoad_Imputed_MW']):
        # Select the last 30 measurements for the same weekday and hour
        recent_data = country_data[
            (country_data['Timestamp'].dt.weekday == row['Timestamp'].weekday()) &
            (country_data['Timestamp'].dt.hour == row['Timestamp'].hour)
        ].tail(30)

        # Fill the missing field with the mean of the last 30 measurements
        imputed_value = recent_data['TotalLoad_Actual_MW'].mean()
        return imputed_value
    else:
        return row['TotalLoad_Imputed_MW']

# Create a copy of the DataFrame data
data_imputed = data.copy()

# Add a column TotalLoad_Imputed_MW with the original data
data_imputed['TotalLoad_Imputed_MW'] = data_imputed['TotalLoad_Actual_MW']

# Unique countries in the DataFrame
unique_countries = data['Country'].unique()

# Loop for each country
for country in unique_countries:
    # Select data only for the specific country
    country_data = data[data['Country'] == country]
    # Find the index of the first non-NaN value in the 'TotalLoad_Actual_MW' column
    first_non_nan_index = country_data['TotalLoad_Actual_MW'].first_valid_index()
    # Trim the DataFrame to that position
    if first_non_nan_index is not None:
        country_data = country_data.loc[first_non_nan_index:]

    # Sort the DataFrame by the Timestamp column
    country_data = country_data.sort_values(by='Timestamp')

    # Apply the imputation function and save the results in the TotalLoad_Imputed_MW column
    data_imputed.loc[data_imputed['Country'] == country, 'TotalLoad_Imputed_MW'] = data_imputed[data_imputed['Country'] == country].apply(impute_missing_values, axis=1)

# Restore the original order of the DataFrame
data_imputed = data_imputed.sort_values(by='Timestamp')

# %%
# Setting the index to 'Timestamp'.
data_imputed.set_index('Timestamp', inplace=True)

# Resampling and grouping by weeks
weekly_imputed_data = data_imputed.groupby('Country')[['TotalLoad_Actual_MW', 'TotalLoad_Imputed_MW']].resample('W').sum().reset_index()  
weekly_imputed_data = weekly_imputed_data.rename(columns={'Timestamp': 'Date'})
weekly_imputed_data = weekly_imputed_data.groupby('Country').apply(remove_first_last).reset_index(drop=True)
weekly_imputed_data = weekly_imputed_data.reset_index()

# %% [markdown]
# ### Plots

# %% [markdown]
# _TotalLoad_Actual_MW per country **after imputation**._

# %%
country_list = weekly_imputed_data['Country'].unique()
for country in country_list:
    electricity_consumption_per_country = weekly_imputed_data[weekly_imputed_data['Country'] == country]
    electricity_consumption_per_country = electricity_consumption_per_country.reset_index(drop=True)
    electricity_consumption_per_country.drop(columns="index", inplace=True)

    electricity_consumption_per_country = weekly_imputed_data[weekly_imputed_data['Country'] == country].copy()
    electricity_consumption_per_country['Date'] = pd.to_datetime(electricity_consumption_per_country['Date'])
    electricity_consumption_per_country['TotalLoad_Actual_MW'].replace(0, np.nan, inplace=True)

    # Find the index of the first non-NaN value in the 'TotalLoad_Actual_MW' column
    first_non_nan_index = electricity_consumption_per_country['TotalLoad_Actual_MW'].first_valid_index()

    # Trim the DataFrame from that position
    if first_non_nan_index is not None:
        electricity_consumption_per_country = electricity_consumption_per_country.loc[first_non_nan_index:]
    
    plt.style.use('seaborn-v0_8')
    plt.rcParams['font.family'] = 'Times New Roman'
    
    plt.figure(figsize=(20, 5))
    plt.ylabel("Electricity Consumption (Terawatts)", fontsize=14)
    plt.title(f"Imputed Electricity Consumption in Terawatts for Country: {country}", fontsize=16)
    
    formatter = ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(False)
    formatter.set_powerlimits((-6, 6))
    plt.gca().yaxis.set_major_formatter(formatter)
    
    plt.plot(electricity_consumption_per_country["Date"], electricity_consumption_per_country["TotalLoad_Actual_MW"], color='firebrick', label='Actual')
    plt.plot(electricity_consumption_per_country["Date"], electricity_consumption_per_country["TotalLoad_Imputed_MW"], color='steelblue', label='Imputed')
    
    plt.xlim(electricity_consumption_per_country["Date"].iloc[0], electricity_consumption_per_country["Date"].iloc[-1])
    plt.legend()
    
    ticks = plt.gca().get_yticks()
    tick_labels = [f'{int(tick) / 1000000:.1f}' for tick in ticks]
    plt.gca().yaxis.set_major_locator(ticker.FixedLocator(ticks))
    plt.gca().set_yticklabels(tick_labels)

    output_file_path = os.path.join(images_output_folder, f"imputed_electricity_consumption_{country}.png")
    if not os.path.exists(output_file_path):
        plt.savefig(output_file_path)
    
    plt.close()

# %% [markdown]
# ### Final data preparation for models

# %%
data_for_the_model = weekly_imputed_data[['Country', 'Date', 'TotalLoad_Imputed_MW']]
data_for_the_model.loc[:, 'Date'] = pd.to_datetime(data_for_the_model['Date'])
(data_for_the_model.head(5)).style.hide(axis = 0).to_latex(os.path.join(tables_output_folder, "tab_06.tex"))

# %% [markdown]
# # PREDICTIONS

# %% [markdown]
# ## METRICS

# %%
def MAPE(y, y_pred):
    mape = np.mean(np.abs((y - y_pred)/y))*100
    return round(mape, 2)

def ME(y, y_pred):
    me = np.mean(y_pred - y)
    return round(me, 2)

def RMSE(MSE):
    rmse = math.sqrt(MSE)
    return round(rmse, 2)

# %% [markdown]
# ## MODELS

# %% [markdown]
# ### SARIMA

# %% [markdown]
# #### Searching for optimal parameters

# %% [markdown]
# The **sarima_split_best_params_search_fit_predict_plot()** function was employed to discover the optimal parameters for SARIMA models for each country, as well as to evaluate the model performance using the selected parameters.

# %%
# def sarima_split_best_params_search_fit_predict_plot(country_name, data):
    
#     dataset = data.values
#     train_data = data[data.index <= '2019-12-31']
#     test_data = data[data.index >= '2020-01-01']
    
#     p = range(0, 2)
#     d = range(0, 2)
#     q = range(0, 2)
#     P = range(0, 2)
#     D = range(1, 2)
#     Q = range(0, 2)
#     s = 12

#     best_aic = float("inf")
#     best_params = None

#     for p_val in p:
#         for d_val in d:
#             for q_val in q:
#                 for P_val in P:
#                     for D_val in D:
#                         for Q_val in Q:
#                             try:
#                                 model = SARIMAX(train_data, order=(p_val, d_val, q_val), seasonal_order=(P_val, D_val, Q_val, s))
#                                 fit_model = model.fit()
#                                 aic = fit_model.aic
#                                 if aic < best_aic:
#                                     best_aic = aic
#                                     best_params = (p_val, d_val, q_val, P_val, D_val, Q_val)
#                             except:
#                                 continue

#     print(f"Best SARIMA parameters for {country_name}:", best_params)

#     results = {
#         'country': country_name,
#         'best_params': best_params,
#     }
    
#     try:
#         p_val, d_val, q_val, P_val, D_val, Q_val = best_params
#         s = 52 
#         model = SARIMAX(train_data, order=(p_val, d_val, q_val), seasonal_order=(P_val, D_val, Q_val, s))
#         fit_model = model.fit()
#         yhat = fit_model.predict(start=len(train_data), end=(len(dataset)-1))
    
#         pd.DataFrame(yhat).plot()
#         data.plot(figsize=(20, 5))
#         plt.legend()
#     except TypeError:
#         pass
    
#     return results

# results_list = []

# for country in data_for_the_model['Country'].unique():
#     try: 
#         print(f'Evaluation for country: {country}')
#         country_data = data_for_the_model[data_for_the_model['Country'] == country].set_index('Date').asfreq('W')
#         results = sarima_split_best_params_search_fit_predict_plot(country, country_data["TotalLoad_Imputed_MW"])
#         results_list.append(results)
#     except Exception as e:
#         print(f"An error occurred for country {country}: {e}")

# sarima_best_params = {results['country']: results['best_params'] for results in results_list}

# sarima_best_params_df = pd.DataFrame(results_list)
# display(sarima_best_params_df)
# Out:
# Evaluation for country: Austria
# Best SARIMA parameters for Austria: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Croatia
# Best SARIMA parameters for Croatia: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Cyprus
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Best SARIMA parameters for Cyprus: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Czech Republic
# Best SARIMA parameters for Czech Republic: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Denmark
# Best SARIMA parameters for Denmark: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Estonia
# Best SARIMA parameters for Estonia: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Finland
# Best SARIMA parameters for Finland: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: France
# Best SARIMA parameters for France: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Germany
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Best SARIMA parameters for Germany: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Greece
# Best SARIMA parameters for Greece: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Hungary
# Best SARIMA parameters for Hungary: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Ireland
# Best SARIMA parameters for Ireland: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Italy
# Best SARIMA parameters for Italy: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Latvia
# Best SARIMA parameters for Latvia: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Lithuania
# Best SARIMA parameters for Lithuania: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Luxembourg
# Best SARIMA parameters for Luxembourg: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Poland
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Best SARIMA parameters for Poland: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Portugal
# Best SARIMA parameters for Portugal: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Romania
# Best SARIMA parameters for Romania: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Slovakia
# Best SARIMA parameters for Slovakia: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Slovenia
# Best SARIMA parameters for Slovenia: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\core.py:509: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# Evaluation for country: Spain
# Best SARIMA parameters for Spain: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Evaluation for country: Sweden
# Best SARIMA parameters for Sweden: (0, 1, 0, 1, 1, 1)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#            country         best_params
# 0          Austria  (0, 1, 0, 1, 1, 1)
# 1          Croatia  (0, 1, 0, 1, 1, 1)
# 2           Cyprus  (0, 1, 0, 1, 1, 1)
# 3   Czech Republic  (0, 1, 0, 1, 1, 1)
# 4          Denmark  (0, 1, 0, 1, 1, 1)
# 5          Estonia  (0, 1, 0, 1, 1, 1)
# 6          Finland  (0, 1, 0, 1, 1, 1)
# 7           France  (0, 1, 0, 1, 1, 1)
# 8          Germany  (0, 1, 0, 1, 1, 1)
# 9           Greece  (0, 1, 0, 1, 1, 1)
# 10         Hungary  (0, 1, 0, 1, 1, 1)
# 11         Ireland  (0, 1, 0, 1, 1, 1)
# 12           Italy  (0, 1, 0, 1, 1, 1)
# 13          Latvia  (0, 1, 0, 1, 1, 1)
# 14       Lithuania  (0, 1, 0, 1, 1, 1)
# 15      Luxembourg  (0, 1, 0, 1, 1, 1)
# 16          Poland  (0, 1, 0, 1, 1, 1)
# 17        Portugal  (0, 1, 0, 1, 1, 1)
# 18         Romania  (0, 1, 0, 1, 1, 1)
# 19        Slovakia  (0, 1, 0, 1, 1, 1)
# 20        Slovenia  (0, 1, 0, 1, 1, 1)
# 21           Spain  (0, 1, 0, 1, 1, 1)
# 22          Sweden  (0, 1, 0, 1, 1, 1)

# %% [markdown]
# #### Model Fitting, Prediction, Plotting, and Evaluation

# %%
def sarima_fit_predict_plot_evaluate(country_name, country_data, best_params):
    dataset = country_data.values
    train_data = country_data[country_data.index <= '2019-12-31']
    test_data = country_data[country_data.index >= '2020-01-01']
    
    s = 52

    p_val, d_val, q_val, P_val, D_val, Q_val = best_params

    model = SARIMAX(train_data, order=(p_val, d_val, q_val), seasonal_order=(P_val, D_val, Q_val, s))
    fit_model = model.fit()
    yhat = fit_model.predict(start=len(train_data), end=(len(dataset)-1))

    model_filename = f"sarima_model_{country_name}.pkl"
    model_file_path = os.path.join(models_output_folder, model_filename)

    if not os.path.exists(model_file_path):
        with open(model_file_path, 'wb') as model_file:
            pickle.dump(fit_model, model_file)

    plt.style.use('seaborn-v0_8')
    plt.rcParams['font.family'] = 'Times New Roman'
    
    plt.figure(figsize=(20, 5))
    plt.ylabel("Electricity Consumption (Terawatts)", fontsize=14)
    plt.title(f"SARIMA Prediction for Electricity Consumption in Terawatts for Country: {country_name}", fontsize=16)

    yhat_df = pd.DataFrame(yhat)
    country_data_subset = country_data.iloc[1:-1]  
    yhat_df_subset = yhat_df.iloc[1:-1]
    
    formatter = ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(False)  
    formatter.set_powerlimits((-6, 6))  
    plt.gca().yaxis.set_major_formatter(formatter)
    
    plt.plot(yhat_df_subset, color="firebrick", label='Predicted')
    plt.plot(country_data_subset, color='steelblue', label='Actual')
    
    plt.xlim(country_data_subset.index[0], country_data_subset.index[-1])
    plt.legend()
    
    # Changing the Y-axis value labels from 5000000 to 5.0
    plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])

    output_file_path = os.path.join(images_output_folder, f"sarima_predictions_{country}.png")
    if not os.path.exists(output_file_path):
        plt.savefig(output_file_path)
    
    plt.close()
    
    MAPE_metric = MAPE(test_data, yhat)
    ME_metric = ME(test_data, yhat)
    MAE_metric = round(mean_absolute_error(test_data, yhat), 2)
    MSE_metric = round(mean_squared_error(test_data, yhat), 2)
    RMSE_metric = RMSE(MSE_metric)

    results = {
        'model': 'sarima',
        'country': country_name,
        'mape': MAPE_metric,
        'me': ME_metric,
        'mae': MAE_metric,
        'mse': MSE_metric,
        'rmse': RMSE_metric
    }
    
    return results

# Dictionary of best SARIMA parameters obtained using sarima_split_best_params_search_fit_predict_plot() function.
sarima_best_params = {
    'Austria': (0, 1, 0, 1, 1, 1),
    'Croatia': (0, 1, 0, 1, 1, 1),
    'Cyprus': (0, 1, 0, 1, 1, 1),
    'Czech Republic': (0, 1, 0, 1, 1, 1),
    'Denmark': (0, 1, 0, 1, 1, 1),
    'Estonia': (0, 1, 0, 1, 1, 1),
    'Finland': (0, 1, 0, 1, 1, 1),
    'France': (0, 1, 0, 1, 1, 1),
    'Germany': (0, 1, 0, 1, 1, 1),
    'Greece': (0, 1, 0, 1, 1, 1),
    'Hungary': (0, 1, 0, 1, 1, 1),
    'Ireland': (0, 1, 0, 1, 1, 1),
    'Italy': (0, 1, 0, 1, 1, 1),
    'Latvia': (0, 1, 0, 1, 1, 1),
    'Lithuania': (0, 1, 0, 1, 1, 1),
    'Luxembourg': (0, 1, 0, 1, 1, 1),
    'Poland': (0, 1, 0, 1, 1, 1),
    'Portugal': (0, 1, 0, 1, 1, 1),
    'Romania': (0, 1, 0, 1, 1, 1),
    'Slovakia': (0, 1, 0, 1, 1, 1),
    'Slovenia': (0, 1, 0, 1, 1, 1),
    'Spain': (0, 1, 0, 1, 1, 1),
    'Sweden': (0, 1, 0, 1, 1, 1)
}

results_list = []

for country in data_for_the_model['Country'].unique():
    try: 
        print(f'Evaluation for country: {country}')
        country_data = data_for_the_model[data_for_the_model['Country'] == country].set_index('Date').asfreq('W')
        best_params = sarima_best_params.get(country)
        if best_params is None:
            print(f"No parameters found for country: {country}")
            continue
        results = sarima_fit_predict_plot_evaluate(country, country_data["TotalLoad_Imputed_MW"], best_params)
        results_list.append(results)
    except Exception as e:
        print(f"An error occurred for country {country}: {e}")

sarima_results = pd.DataFrame(results_list)
# Out:
# Evaluation for country: Austria
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Croatia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Cyprus
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Czech Republic
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Denmark
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Estonia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Finland
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: France
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Germany
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Greece
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Hungary
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Ireland
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Italy
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Latvia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Lithuania
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Luxembourg
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Poland
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Portugal
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Romania
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Slovakia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Slovenia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Spain
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Sweden
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1291630076.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])

# %% [markdown]
# ### AUTO ARIMA

# %% [markdown]
# The auto_arima_split_best_params_search_fit_predict_plot() function was employed to discover the optimal parameters for AUTO ARIMA models for each country using the parameters selected by itself.

# %%
# def auto_arima_fit_predict_plot_evaluate(country_name, country_data):
#     dataset = country_data.values
#     train_data = country_data[country_data.index <= '2019-12-31']
#     test_data = country_data[country_data.index >= '2020-01-01']

#     # Automatyczne dopasowanie modelu ARIMA
#     model = auto_arima(train_data, seasonal=True, m=52)
#     fit_model = model.fit(train_data)

#     # Prognoza na danych testowych
#     yhat, conf_int = fit_model.predict(n_periods=len(test_data), return_conf_int=True)

#     # Zapisz model
#     model_filename = f"auto_arima_model_{country_name}.pkl"
#     model_file_path = os.path.join(models_output_folder, model_filename)

#     if not os.path.exists(model_file_path):
#         with open(model_file_path, 'wb') as model_file:
#             pickle.dump(fit_model, model_file)

#     # Wykres
#     plt.style.use('seaborn-v0_8')
#     plt.rcParams['font.family'] = 'Times New Roman'

#     plt.figure(figsize=(20, 5))
#     plt.ylabel("Electricity Consumption (Terawatts)", fontsize=14)
#     plt.title(f"AUTO ARIMA Prediction for Electricity Consumption in Terawatts for Country: {country_name}", fontsize=16)

#     country_data_subset = country_data.iloc[1:-1]  
#     yhat_df_subset = pd.DataFrame(yhat, index=test_data.index[1:-1])

#     formatter = ticker.ScalarFormatter(useMathText=True)
#     formatter.set_scientific(False)  
#     formatter.set_powerlimits((-6, 6))  
#     plt.gca().yaxis.set_major_formatter(formatter)

#     # Wykres predykcji i danych rzeczywistych
#     plt.plot(yhat_df_subset, color="firebrick", label='Predicted')
#     plt.plot(country_data_subset, color='steelblue', label='Actual')

#     plt.xlim(country_data_subset.index[0], country_data_subset.index[-1])
#     plt.legend()

#     # Zmiana etykiet na osi Y z 5000000 na 5.0
#     plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])

#     output_file_path = os.path.join(images_output_folder, f"auto_arima_predictions_{country}.png")
#     if not os.path.exists(output_file_path):
#         plt.savefig(output_file_path)

#     plt.close()

#     # Miary oceny
#     MAPE_metric = MAPE(test_data, yhat)
#     ME_metric = ME(test_data, yhat)
#     MAE_metric = round(mean_absolute_error(test_data, yhat), 2)
#     MSE_metric = round(mean_squared_error(test_data, yhat), 2)
#     RMSE_metric = RMSE(MSE_metric)

#     results = {
#         'model': 'auto_arima',
#         'country': country_name,
#         'mape': MAPE_metric,
#         'me': ME_metric,
#         'mae': MAE_metric,
#         'mse': MSE_metric,
#         'rmse': RMSE_metric
#     }

#     return results

# results_list = []

# for country in data_for_the_model['Country'].unique():
#     try: 
#         print(f'Evaluation for country: {country}')
#         country_data = data_for_the_model[data_for_the_model['Country'] == country].set_index('Date').asfreq('W')
        
#         results = auto_arima_fit_predict_plot_evaluate(country, country_data["TotalLoad_Imputed_MW"])
#         results_list.append(results)
#     except Exception as e:
#         print(f"An error occurred for country {country}: {e}")

# auto_arima_results = pd.DataFrame(results_list)

# %% [markdown]
# ### TBATS

# %% [markdown]
# #### Searching for optimal parameters

# %% [markdown]
# The **tbats_split_best_params_search_fit_predict()** function was employed to discover the optimal parameters for TBATS models for each country, as well as to evaluate the model performance using the selected parameters.

# %%
# tbats_best_params = {}

# def tbats_split_best_params_search_fit_predict(country_name, data):
    
#     dataset = data.values
#     train_data = data[data.index <= '2019-12-31']
#     test_data = data[data.index >= '2020-01-01']
    
#     seasonal_periods = 52
#     use_arma_errors = True
#     use_box_cox_options = [True, False]
#     use_trend_options = [True, False]
#     n_jobs_option = os.cpu_count()
#     use_damped_trend = True
    
#     best_aic = float("inf")
#     best_params = None
#     best_result_dict = None

#     for use_box_cox in use_box_cox_options:
#         for use_trend in use_trend_options:
#             try:
#                 model = TBATS(seasonal_periods=[seasonal_periods],
#                               use_arma_errors=use_arma_errors,
#                               use_box_cox=use_box_cox,
#                               use_trend=use_trend,
#                               n_jobs=n_jobs_option,
#                               use_damped_trend=use_damped_trend
#                              )
#                 fit_model = model.fit(train_data)
#                 aic = fit_model.aic
#                 if aic < best_aic:
#                     best_aic = aic
#                     best_params = (
#                         seasonal_periods, 
#                         use_arma_errors, 
#                         use_box_cox,
#                         use_trend, 
#                         n_jobs_option,
#                         use_damped_trend
#                         )
#                     best_result_dict = {
#                     "country": country_name,
#                     "seasonal_period": seasonal_periods,
#                     "use_arma_errors": use_arma_errors,
#                     "use_box_cox": use_box_cox,
#                     "use_trend": use_trend,
#                     "use_damped_trend": use_damped_trend
#                 }
#             except:
#                 continue

#     tbats_best_params[country_name] = best_result_dict

#     print(f'Best params for country {country_name}: {best_params}')
    
#     results = {
#         'country': country_name,
#         'best_params': best_params,
#     }
    
#     return(results)

# results_list = []

# for country in data_for_the_model['Country'].unique():
#     try: 
#         print(f'Evaluation for country: {country}')
#         country_data = data_for_the_model[data_for_the_model['Country'] == country].set_index('Date').asfreq('W')
#         results = tbats_split_best_params_search_fit_predict(country, country_data["TotalLoad_Imputed_MW"])
#         results_list.append(results)
#     except Exception as e:
#         print(f"An error occurred for country {country}: {e}")

# tbats_best_params = {results['country']: results['best_params'] for results in results_list}

# tbats_best_params_df = pd.DataFrame(results_list)
# display(tbats_best_params_df)
# Out:
# Evaluation for country: Austria
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Austria: (52, True, False, False, 4, True)
# Evaluation for country: Croatia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Croatia: (52, True, True, False, 4, True)
# Evaluation for country: Cyprus
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Cyprus: (52, True, False, False, 4, True)
# Evaluation for country: Czech Republic
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Czech Republic: (52, True, True, True, 4, True)
# Evaluation for country: Denmark
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Denmark: (52, True, True, False, 4, True)
# Evaluation for country: Estonia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Estonia: (52, True, True, False, 4, True)
# Evaluation for country: Finland
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Finland: (52, True, True, False, 4, True)
# Evaluation for country: France
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country France: (52, True, True, False, 4, True)
# Evaluation for country: Germany
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Germany: (52, True, False, False, 4, True)
# Evaluation for country: Greece
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Greece: (52, True, True, False, 4, True)
# Evaluation for country: Hungary
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Hungary: (52, True, False, False, 4, True)
# Evaluation for country: Ireland
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Ireland: (52, True, False, False, 4, True)
# Evaluation for country: Italy
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Italy: (52, True, True, False, 4, True)
# Evaluation for country: Latvia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Latvia: (52, True, True, False, 4, True)
# Evaluation for country: Lithuania
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Lithuania: (52, True, False, True, 4, True)
# Evaluation for country: Luxembourg
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Luxembourg: (52, True, False, False, 4, True)
# Evaluation for country: Poland
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Poland: (52, True, False, False, 4, True)
# Evaluation for country: Portugal
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Portugal: (52, True, False, False, 4, True)
# Evaluation for country: Romania
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Romania: (52, True, True, True, 4, True)
# Evaluation for country: Slovakia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Slovakia: (52, True, True, True, 4, True)
# Evaluation for country: Slovenia
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Slovenia: (52, True, False, False, 4, True)
# Evaluation for country: Spain
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Spain: (52, True, False, False, 4, True)
# Evaluation for country: Sweden
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Best params for country Sweden: (52, True, True, False, 4, True)
#            country                        best_params
# 0          Austria  (52, True, False, False, 4, True)
# 1          Croatia   (52, True, True, False, 4, True)
# 2           Cyprus  (52, True, False, False, 4, True)
# 3   Czech Republic    (52, True, True, True, 4, True)
# 4          Denmark   (52, True, True, False, 4, True)
# 5          Estonia   (52, True, True, False, 4, True)
# 6          Finland   (52, True, True, False, 4, True)
# 7           France   (52, True, True, False, 4, True)
# 8          Germany  (52, True, False, False, 4, True)
# 9           Greece   (52, True, True, False, 4, True)
# 10         Hungary  (52, True, False, False, 4, True)
# 11         Ireland  (52, True, False, False, 4, True)
# 12           Italy   (52, True, True, False, 4, True)
# 13          Latvia   (52, True, True, False, 4, True)
# 14       Lithuania   (52, True, False, True, 4, True)
# 15      Luxembourg  (52, True, False, False, 4, True)
# 16          Poland  (52, True, False, False, 4, True)
# 17        Portugal  (52, True, False, False, 4, True)
# 18         Romania    (52, True, True, True, 4, True)
# 19        Slovakia    (52, True, True, True, 4, True)
# 20        Slovenia  (52, True, False, False, 4, True)
# 21           Spain  (52, True, False, False, 4, True)
# 22          Sweden   (52, True, True, False, 4, True)

# %% [markdown]
# #### Model Fitting, Prediction, Plotting, and Evaluation

# %%
def tbats_fit_predict_plot_evaluate(country_name, country_data, best_params):

    dataset = country_data.values
    train_data = country_data[country_data.index <= '2019-12-31']
    test_data = country_data[country_data.index >= '2020-01-01']

    (
    seasonal_period, 
    use_arma_errors, 
    use_box_cox,
    use_trend, 
    n_jobs_option,
    use_damped_trend
    ) = best_params
    
    model = TBATS(seasonal_periods=[seasonal_period],
                                    use_arma_errors=use_arma_errors,
                                    use_box_cox=use_box_cox,
                                    use_trend=use_trend,
                                    n_jobs=n_jobs_option,
                                    use_damped_trend=use_damped_trend
                                    )
    fit_model = model.fit(train_data)
    yhat = fit_model.forecast(steps=len(test_data))

    model_filename = f"tbats_model_{country_name}.pkl"
    model_file_path = os.path.join(models_output_folder, model_filename)

    if not os.path.exists(model_file_path):
        with open(model_file_path, 'wb') as model_file:
            pickle.dump(fit_model, model_file)

    start_date = '2020-01-07'
    end_date = '2021-09-05'
    date_range = pd.date_range(start=start_date, end=end_date, freq='7D')

    yhat_df = pd.DataFrame(yhat, index=date_range)
    yhat_df_subset = yhat_df.iloc[1:-1]

    country_data_subset = country_data.iloc[1:-1] 

    plt.style.use('seaborn-v0_8')
    plt.rcParams['font.family'] = 'Times New Roman'
    
    plt.figure(figsize=(20, 5))
    plt.ylabel("Electricity Consumption (Terawatts)", fontsize=14)
    plt.title(f"TBATS Prediction for Electricity Consumption in Terawatts for Country: {country_name}", fontsize=16)
    
    formatter = ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(False)
    formatter.set_powerlimits((-6, 6))
    plt.gca().yaxis.set_major_formatter(formatter)
    
    plt.plot(yhat_df_subset, color="firebrick", label='Predicted')
    plt.plot(country_data_subset, color='steelblue', label='Actual')
    
    plt.xlim(country_data_subset.index[0], country_data_subset.index[-1])
    plt.legend()
    
    plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])

    output_file_path = os.path.join(images_output_folder, f"tbats_predictions_{country}.png")
    if not os.path.exists(output_file_path):
        plt.savefig(output_file_path)
    
    plt.close()

    MAPE_metric = MAPE(test_data, yhat)
    ME_metric = ME(test_data, yhat)
    MAE_metric = round(mean_absolute_error(test_data, yhat), 2)
    MSE_metric = round(mean_squared_error(test_data, yhat), 2)
    RMSE_metric = RMSE(MSE_metric)

    results = {
        'model': 'tbats',
        'country': country_name,
        'mape': MAPE_metric,
        'me': ME_metric,
        'mae': MAE_metric,
        'mse': MSE_metric,
        'rmse': RMSE_metric
    }

    return results

# Dictionary of best TBATS parameters obtained using tbats_split_best_params_search_fit_predict() function
tbats_best_params = {
    'Austria': (52, True, False, False, 4, True),
    'Croatia': (52, True, True, False, 4, True),
    'Cyprus': (52, True, False, False, 4, True),
    'Czech Republic': (52, True, True, True, 4, True),
    'Denmark': (52, True, True, False, 4, True),
    'Estonia': (52, True, True, False, 4, True),
    'Finland': (52, True, True, False, 4, True),
    'France': (52, True, True, False, 4, True),
    'Germany': (52, True, False, False, 4, True),
    'Greece': (52, True, True, False, 4, True),
    'Hungary': (52, True, False, False, 4, True),
    'Ireland': (52, True, False, False, 4, True),
    'Italy': (52, True, True, False, 4, True),
    'Latvia': (52, True, True, False, 4, True),
    'Lithuania': (52, True, False, True, 4, True),
    'Luxembourg': (52, True, False, False, 4, True),
    'Poland': (52, True, False, False, 4, True),
    'Portugal': (52, True, False, False, 4, True),
    'Romania': (52, True, True, True, 4, True),
    'Slovakia': (52, True, True, True, 4, True),
    'Slovenia': (52, True, False, False, 4, True),
    'Spain': (52, True, False, False, 4, True),
    'Sweden': (52, True, True, False, 4, True)
}

results_list = []

for country in data_for_the_model['Country'].unique():
    try: 
        print(f'Evaluation for country: {country}')
        country_data = data_for_the_model[data_for_the_model['Country'] == country].set_index('Date').asfreq('W')
        best_params = tbats_best_params.get(country)
        if best_params is None:
            print(f"No parameters found for country: {country}")
            continue
        results = tbats_fit_predict_plot_evaluate(country, country_data["TotalLoad_Imputed_MW"], best_params)
        results_list.append(results)
    except Exception as e:
        print(f"An error occurred for country {country}: {e}")

tbats_results = pd.DataFrame(results_list)
# Out:
# Evaluation for country: Austria
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Evaluation for country: Croatia
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Cyprus
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Czech Republic
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Denmark
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Evaluation for country: Estonia
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Evaluation for country: Finland
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Evaluation for country: France
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Germany
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Greece
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Evaluation for country: Hungary
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Evaluation for country: Ireland
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Italy
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Evaluation for country: Latvia
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Lithuania
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Luxembourg
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Poland
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Evaluation for country: Portugal
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Romania
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Slovakia
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# Evaluation for country: Slovenia
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Spain
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# Evaluation for country: Sweden
# C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tbats\error\ExceptionHandler.py:13: InputArgsWarning: When use_damped_trend can be used only with use_trend. Setting damped trend to False.
#   warnings.warn(message, warning_type)
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2536259025.py:60: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])

# %% [markdown]
# ### LSTM

# %% [markdown]
# #### Model Fitting, Prediction, Plotting, and Evaluation

# %%
def lstm_fit_predict_plot_evaluate(country_name, country_data):
    
    dataset = country_data.values
    train_data = country_data[country_data.index <= '2019-12-31']
    test_data = country_data[country_data.index >= '2020-01-01']
    
    look_back = 10

    scaler = MinMaxScaler(feature_range=(-1, 1))
    train_data = scaler.fit_transform(train_data.values.reshape(-1, 1))
    test_data_rescaled = scaler.transform(test_data.values.reshape(-1, 1))
    
    def prepare_data(data, look_back=10):
        X, y = [], []
        for i in range(len(data) - look_back):
            X.append(data[i:i + look_back])
            y.append(data[i + look_back])
        return np.array(X), np.array(y)

    X_train, y_train = prepare_data(train_data, look_back)
    X_test, y_test = prepare_data(test_data_rescaled, look_back)

    model = Sequential()
    model.add(LSTM(64, input_shape=(look_back, 1), return_sequences=True))  # Dodana warstwa LSTM
    model.add(LSTM(64))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', metrics=["mape"], optimizer='adam')
    
    fit_model = model.fit(X_train, y_train, epochs=300, batch_size=1, verbose=2)

    yhat = model.predict(X_test)
    predictions_rescaled = scaler.inverse_transform(yhat)
    yhat_df = pd.DataFrame(predictions_rescaled, index=test_data.index[look_back:])

    model_filename = f"lstm_model_{country_name}.pkl"
    model_file_path = os.path.join(models_output_folder, model_filename)

    if not os.path.exists(model_file_path):
        with open(model_file_path, 'wb') as model_file:
            pickle.dump(fit_model, model_file)

    country_data_subset = country_data.iloc[1:-1] 

    plt.style.use('seaborn-v0_8')
    plt.rcParams['font.family'] = 'Times New Roman'
    
    plt.figure(figsize=(20, 5))
    plt.ylabel("Electricity Consumption (Terawatts)", fontsize=14)
    plt.title(f"LSTM Prediction for Electricity Consumption in Terawatts for Country: {country_name}", fontsize=16)
    
    country_data_subset = country_data.iloc[1:-1] 
    yhat_df_subset = yhat_df.iloc[1:-1]
    
    formatter = ticker.ScalarFormatter(useMathText=True)
    formatter.set_scientific(False)
    formatter.set_powerlimits((-6, 6))
    plt.gca().yaxis.set_major_formatter(formatter)
    
    plt.plot(yhat_df_subset, color="firebrick", label='Predicted')
    plt.plot(country_data_subset, color='steelblue', label='Actual')
    
    plt.xlim(country_data_subset.index[0], country_data_subset.index[-1])
    plt.legend()
    
    plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])

    output_file_path = os.path.join(images_output_folder, f"lstm_predictions_{country}.png")
    if not os.path.exists(output_file_path):
        plt.savefig(output_file_path)
    
    plt.close()

    MAPE_metric = MAPE(test_data.iloc[look_back:], yhat_df)
    ME_metric = ME(test_data.iloc[look_back:], yhat_df)
    MAE_metric = round(mean_absolute_error(test_data.iloc[look_back:], yhat_df), 2)
    MSE_metric = round(mean_squared_error(test_data.iloc[look_back:], yhat_df), 2)
    RMSE_metric = RMSE(MSE_metric)

    results = {
        'model': 'lstm',
        'country': country_name,
        'mape': MAPE_metric,
        'me': ME_metric,
        'mae': MAE_metric,
        'mse': MSE_metric,
        'rmse': RMSE_metric
    }
    
    return fit_model, results

results_list = []

for country in data_for_the_model['Country'].unique():
    try: 
        print(f'Evaluation for country: {country}')
        country_data = data_for_the_model[data_for_the_model['Country'] == country].set_index('Date').asfreq('W')
        country_history, country_results = lstm_fit_predict_plot_evaluate(country, country_data["TotalLoad_Imputed_MW"])
        locals()[f'history_{country}'] = country_history
        results_list.append(country_results)
    except Exception as e:
        print(f"An error occurred for country {country}: {e}")

lstm_results = pd.DataFrame(results_list)
# Out:
# Evaluation for country: Austria
# Epoch 1/300
# 250/250 - 6s - loss: 0.0942 - mape: 116.5078 - 6s/epoch - 23ms/step
# Epoch 2/300
# 250/250 - 1s - loss: 0.0663 - mape: 101.9206 - 1s/epoch - 6ms/step
# Epoch 3/300
# 250/250 - 1s - loss: 0.0588 - mape: 88.7151 - 1s/epoch - 6ms/step
# Epoch 4/300
# 250/250 - 1s - loss: 0.0511 - mape: 93.3332 - 1s/epoch - 6ms/step
# Epoch 5/300
# 250/250 - 1s - loss: 0.0479 - mape: 98.2387 - 1s/epoch - 6ms/step
# Epoch 6/300
# 250/250 - 1s - loss: 0.0480 - mape: 87.9118 - 1s/epoch - 6ms/step
# Epoch 7/300
# 250/250 - 1s - loss: 0.0465 - mape: 89.6951 - 1s/epoch - 6ms/step
# Epoch 8/300
# 250/250 - 1s - loss: 0.0464 - mape: 96.1443 - 1s/epoch - 6ms/step
# Epoch 9/300
# 250/250 - 1s - loss: 0.0451 - mape: 98.0792 - 1s/epoch - 6ms/step
# Epoch 10/300
# 250/250 - 1s - loss: 0.0449 - mape: 109.9948 - 1s/epoch - 6ms/step
# Epoch 11/300
# 250/250 - 1s - loss: 0.0456 - mape: 109.9807 - 1s/epoch - 6ms/step
# Epoch 12/300
# 250/250 - 1s - loss: 0.0452 - mape: 89.8493 - 1s/epoch - 6ms/step
# Epoch 13/300
# 250/250 - 1s - loss: 0.0443 - mape: 97.1604 - 1s/epoch - 6ms/step
# Epoch 14/300
# 250/250 - 1s - loss: 0.0419 - mape: 91.1406 - 1s/epoch - 6ms/step
# Epoch 15/300
# 250/250 - 1s - loss: 0.0431 - mape: 99.3396 - 1s/epoch - 6ms/step
# Epoch 16/300
# 250/250 - 1s - loss: 0.0413 - mape: 84.3809 - 1s/epoch - 6ms/step
# Epoch 17/300
# 250/250 - 1s - loss: 0.0404 - mape: 91.0297 - 1s/epoch - 6ms/step
# Epoch 18/300
# 250/250 - 2s - loss: 0.0405 - mape: 92.9819 - 2s/epoch - 6ms/step
# Epoch 19/300
# 250/250 - 1s - loss: 0.0386 - mape: 85.4453 - 1s/epoch - 6ms/step
# Epoch 20/300
# 250/250 - 1s - loss: 0.0407 - mape: 88.5052 - 1s/epoch - 6ms/step
# Epoch 21/300
# 250/250 - 1s - loss: 0.0382 - mape: 83.3782 - 1s/epoch - 6ms/step
# Epoch 22/300
# 250/250 - 1s - loss: 0.0374 - mape: 96.3870 - 1s/epoch - 6ms/step
# Epoch 23/300
# 250/250 - 1s - loss: 0.0362 - mape: 104.4252 - 1s/epoch - 6ms/step
# Epoch 24/300
# 250/250 - 1s - loss: 0.0359 - mape: 79.6007 - 1s/epoch - 6ms/step
# Epoch 25/300
# 250/250 - 1s - loss: 0.0365 - mape: 98.1233 - 1s/epoch - 6ms/step
# Epoch 26/300
# 250/250 - 1s - loss: 0.0332 - mape: 102.4980 - 1s/epoch - 6ms/step
# Epoch 27/300
# 250/250 - 1s - loss: 0.0366 - mape: 84.1171 - 1s/epoch - 6ms/step
# Epoch 28/300
# 250/250 - 1s - loss: 0.0336 - mape: 87.5062 - 1s/epoch - 6ms/step
# Epoch 29/300
# 250/250 - 1s - loss: 0.0330 - mape: 88.6915 - 1s/epoch - 6ms/step
# Epoch 30/300
# 250/250 - 1s - loss: 0.0328 - mape: 85.2553 - 1s/epoch - 6ms/step
# Epoch 31/300
# 250/250 - 1s - loss: 0.0309 - mape: 75.0377 - 1s/epoch - 6ms/step
# Epoch 32/300
# 250/250 - 1s - loss: 0.0300 - mape: 88.5117 - 1s/epoch - 6ms/step
# Epoch 33/300
# 250/250 - 1s - loss: 0.0305 - mape: 81.4062 - 1s/epoch - 6ms/step
# Epoch 34/300
# 250/250 - 1s - loss: 0.0299 - mape: 77.9476 - 1s/epoch - 6ms/step
# Epoch 35/300
# 250/250 - 1s - loss: 0.0299 - mape: 108.2573 - 1s/epoch - 6ms/step
# Epoch 36/300
# 250/250 - 1s - loss: 0.0277 - mape: 89.4225 - 1s/epoch - 6ms/step
# Epoch 37/300
# 250/250 - 1s - loss: 0.0277 - mape: 95.1247 - 1s/epoch - 6ms/step
# Epoch 38/300
# 250/250 - 1s - loss: 0.0294 - mape: 98.0343 - 1s/epoch - 6ms/step
# Epoch 39/300
# 250/250 - 1s - loss: 0.0281 - mape: 84.0790 - 1s/epoch - 6ms/step
# Epoch 40/300
# 250/250 - 1s - loss: 0.0264 - mape: 83.9685 - 1s/epoch - 6ms/step
# Epoch 41/300
# 250/250 - 1s - loss: 0.0278 - mape: 92.4326 - 1s/epoch - 6ms/step
# Epoch 42/300
# 250/250 - 1s - loss: 0.0241 - mape: 108.3149 - 1s/epoch - 6ms/step
# Epoch 43/300
# 250/250 - 1s - loss: 0.0247 - mape: 84.8629 - 1s/epoch - 6ms/step
# Epoch 44/300
# 250/250 - 1s - loss: 0.0253 - mape: 89.3659 - 1s/epoch - 6ms/step
# Epoch 45/300
# 250/250 - 1s - loss: 0.0265 - mape: 86.4274 - 1s/epoch - 6ms/step
# Epoch 46/300
# 250/250 - 1s - loss: 0.0249 - mape: 89.4360 - 1s/epoch - 6ms/step
# Epoch 47/300
# 250/250 - 1s - loss: 0.0251 - mape: 91.7148 - 1s/epoch - 6ms/step
# Epoch 48/300
# 250/250 - 1s - loss: 0.0232 - mape: 72.0136 - 1s/epoch - 6ms/step
# Epoch 49/300
# 250/250 - 1s - loss: 0.0234 - mape: 89.9213 - 1s/epoch - 6ms/step
# Epoch 50/300
# 250/250 - 1s - loss: 0.0225 - mape: 70.2132 - 1s/epoch - 6ms/step
# Epoch 51/300
# 250/250 - 1s - loss: 0.0224 - mape: 88.5981 - 1s/epoch - 6ms/step
# Epoch 52/300
# 250/250 - 1s - loss: 0.0233 - mape: 84.2128 - 1s/epoch - 6ms/step
# Epoch 53/300
# 250/250 - 1s - loss: 0.0218 - mape: 80.0563 - 1s/epoch - 6ms/step
# Epoch 54/300
# 250/250 - 1s - loss: 0.0216 - mape: 102.6039 - 1s/epoch - 6ms/step
# Epoch 55/300
# 250/250 - 1s - loss: 0.0222 - mape: 90.7635 - 1s/epoch - 6ms/step
# Epoch 56/300
# 250/250 - 1s - loss: 0.0217 - mape: 86.0232 - 1s/epoch - 6ms/step
# Epoch 57/300
# 250/250 - 1s - loss: 0.0225 - mape: 91.6032 - 1s/epoch - 6ms/step
# Epoch 58/300
# 250/250 - 1s - loss: 0.0230 - mape: 94.1609 - 1s/epoch - 6ms/step
# Epoch 59/300
# 250/250 - 1s - loss: 0.0198 - mape: 85.9805 - 1s/epoch - 6ms/step
# Epoch 60/300
# 250/250 - 1s - loss: 0.0201 - mape: 98.5576 - 1s/epoch - 6ms/step
# Epoch 61/300
# 250/250 - 1s - loss: 0.0209 - mape: 101.9509 - 1s/epoch - 6ms/step
# Epoch 62/300
# 250/250 - 1s - loss: 0.0199 - mape: 97.5389 - 1s/epoch - 6ms/step
# Epoch 63/300
# 250/250 - 1s - loss: 0.0198 - mape: 88.1123 - 1s/epoch - 6ms/step
# Epoch 64/300
# 250/250 - 1s - loss: 0.0194 - mape: 86.4675 - 1s/epoch - 6ms/step
# Epoch 65/300
# 250/250 - 1s - loss: 0.0181 - mape: 73.6499 - 1s/epoch - 6ms/step
# Epoch 66/300
# 250/250 - 1s - loss: 0.0216 - mape: 111.1322 - 1s/epoch - 6ms/step
# Epoch 67/300
# 250/250 - 1s - loss: 0.0181 - mape: 76.3878 - 1s/epoch - 6ms/step
# Epoch 68/300
# 250/250 - 1s - loss: 0.0184 - mape: 77.3458 - 1s/epoch - 6ms/step
# Epoch 69/300
# 250/250 - 1s - loss: 0.0180 - mape: 80.3848 - 1s/epoch - 6ms/step
# Epoch 70/300
# 250/250 - 1s - loss: 0.0168 - mape: 88.2602 - 1s/epoch - 6ms/step
# Epoch 71/300
# 250/250 - 1s - loss: 0.0169 - mape: 72.9324 - 1s/epoch - 6ms/step
# Epoch 72/300
# 250/250 - 1s - loss: 0.0184 - mape: 90.4280 - 1s/epoch - 6ms/step
# Epoch 73/300
# 250/250 - 1s - loss: 0.0234 - mape: 87.9136 - 1s/epoch - 6ms/step
# Epoch 74/300
# 250/250 - 1s - loss: 0.0167 - mape: 86.7768 - 1s/epoch - 6ms/step
# Epoch 75/300
# 250/250 - 1s - loss: 0.0170 - mape: 70.3420 - 1s/epoch - 6ms/step
# Epoch 76/300
# 250/250 - 1s - loss: 0.0154 - mape: 74.0739 - 1s/epoch - 6ms/step
# Epoch 77/300
# 250/250 - 1s - loss: 0.0145 - mape: 84.5754 - 1s/epoch - 6ms/step
# Epoch 78/300
# 250/250 - 1s - loss: 0.0154 - mape: 75.8095 - 1s/epoch - 6ms/step
# Epoch 79/300
# 250/250 - 2s - loss: 0.0155 - mape: 78.3388 - 2s/epoch - 6ms/step
# Epoch 80/300
# 250/250 - 1s - loss: 0.0141 - mape: 79.9063 - 1s/epoch - 6ms/step
# Epoch 81/300
# 250/250 - 1s - loss: 0.0147 - mape: 68.3063 - 1s/epoch - 6ms/step
# Epoch 82/300
# 250/250 - 1s - loss: 0.0141 - mape: 86.1869 - 1s/epoch - 6ms/step
# Epoch 83/300
# 250/250 - 1s - loss: 0.0210 - mape: 100.0142 - 1s/epoch - 6ms/step
# Epoch 84/300
# 250/250 - 1s - loss: 0.0161 - mape: 74.5218 - 1s/epoch - 6ms/step
# Epoch 85/300
# 250/250 - 1s - loss: 0.0131 - mape: 70.9318 - 1s/epoch - 6ms/step
# Epoch 86/300
# 250/250 - 1s - loss: 0.0124 - mape: 85.9553 - 1s/epoch - 6ms/step
# Epoch 87/300
# 250/250 - 1s - loss: 0.0125 - mape: 77.1165 - 1s/epoch - 6ms/step
# Epoch 88/300
# 250/250 - 1s - loss: 0.0117 - mape: 78.3455 - 1s/epoch - 6ms/step
# Epoch 89/300
# 250/250 - 1s - loss: 0.0135 - mape: 86.9622 - 1s/epoch - 6ms/step
# Epoch 90/300
# 250/250 - 1s - loss: 0.0112 - mape: 64.2459 - 1s/epoch - 6ms/step
# Epoch 91/300
# 250/250 - 1s - loss: 0.0122 - mape: 66.5363 - 1s/epoch - 6ms/step
# Epoch 92/300
# 250/250 - 1s - loss: 0.0118 - mape: 80.7993 - 1s/epoch - 6ms/step
# Epoch 93/300
# 250/250 - 1s - loss: 0.0121 - mape: 78.2373 - 1s/epoch - 6ms/step
# Epoch 94/300
# 250/250 - 1s - loss: 0.0119 - mape: 71.6178 - 1s/epoch - 6ms/step
# Epoch 95/300
# 250/250 - 1s - loss: 0.0114 - mape: 58.2101 - 1s/epoch - 6ms/step
# Epoch 96/300
# 250/250 - 1s - loss: 0.0102 - mape: 62.1630 - 1s/epoch - 6ms/step
# Epoch 97/300
# 250/250 - 1s - loss: 0.0094 - mape: 64.1505 - 1s/epoch - 6ms/step
# Epoch 98/300
# 250/250 - 1s - loss: 0.0099 - mape: 68.7767 - 1s/epoch - 6ms/step
# Epoch 99/300
# 250/250 - 1s - loss: 0.0101 - mape: 68.4542 - 1s/epoch - 6ms/step
# Epoch 100/300
# 250/250 - 1s - loss: 0.0091 - mape: 65.7719 - 1s/epoch - 6ms/step
# Epoch 101/300
# 250/250 - 1s - loss: 0.0087 - mape: 76.9111 - 1s/epoch - 6ms/step
# Epoch 102/300
# 250/250 - 1s - loss: 0.0088 - mape: 84.0781 - 1s/epoch - 6ms/step
# Epoch 103/300
# 250/250 - 1s - loss: 0.0070 - mape: 45.1193 - 1s/epoch - 6ms/step
# Epoch 104/300
# 250/250 - 1s - loss: 0.0077 - mape: 60.3843 - 1s/epoch - 6ms/step
# Epoch 105/300
# 250/250 - 1s - loss: 0.0072 - mape: 76.4053 - 1s/epoch - 6ms/step
# Epoch 106/300
# 250/250 - 1s - loss: 0.0077 - mape: 79.0412 - 1s/epoch - 6ms/step
# Epoch 107/300
# 250/250 - 1s - loss: 0.0069 - mape: 48.7137 - 1s/epoch - 6ms/step
# Epoch 108/300
# 250/250 - 1s - loss: 0.0059 - mape: 47.7650 - 1s/epoch - 6ms/step
# Epoch 109/300
# 250/250 - 1s - loss: 0.0070 - mape: 54.5185 - 1s/epoch - 6ms/step
# Epoch 110/300
# 250/250 - 1s - loss: 0.0059 - mape: 54.0686 - 1s/epoch - 6ms/step
# Epoch 111/300
# 250/250 - 1s - loss: 0.0069 - mape: 60.1651 - 1s/epoch - 6ms/step
# Epoch 112/300
# 250/250 - 1s - loss: 0.0061 - mape: 76.6345 - 1s/epoch - 6ms/step
# Epoch 113/300
# 250/250 - 1s - loss: 0.0047 - mape: 46.2575 - 1s/epoch - 6ms/step
# Epoch 114/300
# 250/250 - 1s - loss: 0.0066 - mape: 57.2043 - 1s/epoch - 6ms/step
# Epoch 115/300
# 250/250 - 1s - loss: 0.0060 - mape: 39.9249 - 1s/epoch - 6ms/step
# Epoch 116/300
# 250/250 - 1s - loss: 0.0055 - mape: 63.8570 - 1s/epoch - 6ms/step
# Epoch 117/300
# 250/250 - 1s - loss: 0.0045 - mape: 30.6734 - 1s/epoch - 6ms/step
# Epoch 118/300
# 250/250 - 1s - loss: 0.0041 - mape: 51.0480 - 1s/epoch - 6ms/step
# Epoch 119/300
# 250/250 - 1s - loss: 0.0039 - mape: 37.3482 - 1s/epoch - 6ms/step
# Epoch 120/300
# 250/250 - 1s - loss: 0.0037 - mape: 45.2326 - 1s/epoch - 6ms/step
# Epoch 121/300
# 250/250 - 1s - loss: 0.0041 - mape: 34.5221 - 1s/epoch - 6ms/step
# Epoch 122/300
# 250/250 - 1s - loss: 0.0047 - mape: 63.9887 - 1s/epoch - 6ms/step
# Epoch 123/300
# 250/250 - 1s - loss: 0.0036 - mape: 64.8198 - 1s/epoch - 6ms/step
# Epoch 124/300
# 250/250 - 1s - loss: 0.0035 - mape: 31.3675 - 1s/epoch - 6ms/step
# Epoch 125/300
# 250/250 - 1s - loss: 0.0030 - mape: 34.0713 - 1s/epoch - 6ms/step
# Epoch 126/300
# 250/250 - 1s - loss: 0.0035 - mape: 37.4465 - 1s/epoch - 6ms/step
# Epoch 127/300
# 250/250 - 1s - loss: 0.0032 - mape: 45.3571 - 1s/epoch - 6ms/step
# Epoch 128/300
# 250/250 - 1s - loss: 0.0051 - mape: 42.0750 - 1s/epoch - 6ms/step
# Epoch 129/300
# 250/250 - 1s - loss: 0.0029 - mape: 35.8244 - 1s/epoch - 6ms/step
# Epoch 130/300
# 250/250 - 1s - loss: 0.0024 - mape: 35.5305 - 1s/epoch - 6ms/step
# Epoch 131/300
# 250/250 - 1s - loss: 0.0036 - mape: 42.5748 - 1s/epoch - 6ms/step
# Epoch 132/300
# 250/250 - 1s - loss: 0.0030 - mape: 41.4233 - 1s/epoch - 6ms/step
# Epoch 133/300
# 250/250 - 1s - loss: 0.0030 - mape: 35.4049 - 1s/epoch - 6ms/step
# Epoch 134/300
# 250/250 - 1s - loss: 0.0026 - mape: 53.3753 - 1s/epoch - 6ms/step
# Epoch 135/300
# 250/250 - 1s - loss: 0.0025 - mape: 34.3522 - 1s/epoch - 6ms/step
# Epoch 136/300
# 250/250 - 1s - loss: 0.0025 - mape: 37.6309 - 1s/epoch - 6ms/step
# Epoch 137/300
# 250/250 - 1s - loss: 0.0024 - mape: 33.7787 - 1s/epoch - 6ms/step
# Epoch 138/300
# 250/250 - 1s - loss: 0.0025 - mape: 29.7842 - 1s/epoch - 6ms/step
# Epoch 139/300
# 250/250 - 1s - loss: 0.0020 - mape: 32.7749 - 1s/epoch - 6ms/step
# Epoch 140/300
# 250/250 - 1s - loss: 0.0029 - mape: 30.7460 - 1s/epoch - 6ms/step
# Epoch 141/300
# 250/250 - 1s - loss: 0.0029 - mape: 25.7051 - 1s/epoch - 6ms/step
# Epoch 142/300
# 250/250 - 1s - loss: 0.0029 - mape: 31.0774 - 1s/epoch - 6ms/step
# Epoch 143/300
# 250/250 - 1s - loss: 0.0025 - mape: 26.6862 - 1s/epoch - 6ms/step
# Epoch 144/300
# 250/250 - 1s - loss: 0.0021 - mape: 38.9249 - 1s/epoch - 6ms/step
# Epoch 145/300
# 250/250 - 1s - loss: 0.0023 - mape: 25.6090 - 1s/epoch - 6ms/step
# Epoch 146/300
# 250/250 - 1s - loss: 0.0019 - mape: 29.3673 - 1s/epoch - 6ms/step
# Epoch 147/300
# 250/250 - 1s - loss: 0.0016 - mape: 34.3182 - 1s/epoch - 6ms/step
# Epoch 148/300
# 250/250 - 1s - loss: 0.0017 - mape: 25.6677 - 1s/epoch - 6ms/step
# Epoch 149/300
# 250/250 - 1s - loss: 0.0022 - mape: 40.0921 - 1s/epoch - 6ms/step
# Epoch 150/300
# 250/250 - 1s - loss: 0.0022 - mape: 37.9175 - 1s/epoch - 6ms/step
# Epoch 151/300
# 250/250 - 1s - loss: 0.0026 - mape: 48.3314 - 1s/epoch - 6ms/step
# Epoch 152/300
# 250/250 - 1s - loss: 0.0017 - mape: 29.9169 - 1s/epoch - 6ms/step
# Epoch 153/300
# 250/250 - 1s - loss: 0.0013 - mape: 25.3163 - 1s/epoch - 6ms/step
# Epoch 154/300
# 250/250 - 1s - loss: 0.0014 - mape: 22.2221 - 1s/epoch - 6ms/step
# Epoch 155/300
# 250/250 - 1s - loss: 0.0016 - mape: 38.4847 - 1s/epoch - 6ms/step
# Epoch 156/300
# 250/250 - 1s - loss: 0.0022 - mape: 36.1023 - 1s/epoch - 6ms/step
# Epoch 157/300
# 250/250 - 1s - loss: 0.0024 - mape: 28.9911 - 1s/epoch - 6ms/step
# Epoch 158/300
# 250/250 - 1s - loss: 0.0020 - mape: 31.2140 - 1s/epoch - 6ms/step
# Epoch 159/300
# 250/250 - 1s - loss: 0.0017 - mape: 39.3564 - 1s/epoch - 6ms/step
# Epoch 160/300
# 250/250 - 1s - loss: 0.0026 - mape: 40.7219 - 1s/epoch - 6ms/step
# Epoch 161/300
# 250/250 - 1s - loss: 0.0023 - mape: 30.8043 - 1s/epoch - 6ms/step
# Epoch 162/300
# 250/250 - 1s - loss: 0.0014 - mape: 31.8833 - 1s/epoch - 6ms/step
# Epoch 163/300
# 250/250 - 2s - loss: 0.0017 - mape: 26.7213 - 2s/epoch - 6ms/step
# Epoch 164/300
# 250/250 - 1s - loss: 0.0022 - mape: 28.2787 - 1s/epoch - 6ms/step
# Epoch 165/300
# 250/250 - 1s - loss: 0.0012 - mape: 22.4716 - 1s/epoch - 6ms/step
# Epoch 166/300
# 250/250 - 1s - loss: 0.0015 - mape: 22.0520 - 1s/epoch - 6ms/step
# Epoch 167/300
# 250/250 - 1s - loss: 0.0011 - mape: 27.3741 - 1s/epoch - 6ms/step
# Epoch 168/300
# 250/250 - 1s - loss: 9.1856e-04 - mape: 31.9012 - 1s/epoch - 6ms/step
# Epoch 169/300
# 250/250 - 1s - loss: 9.9697e-04 - mape: 17.0320 - 1s/epoch - 6ms/step
# Epoch 170/300
# 250/250 - 1s - loss: 0.0013 - mape: 25.5631 - 1s/epoch - 6ms/step
# Epoch 171/300
# 250/250 - 1s - loss: 0.0016 - mape: 31.0440 - 1s/epoch - 6ms/step
# Epoch 172/300
# 250/250 - 1s - loss: 0.0013 - mape: 29.3483 - 1s/epoch - 6ms/step
# Epoch 173/300
# 250/250 - 1s - loss: 0.0019 - mape: 30.7480 - 1s/epoch - 6ms/step
# Epoch 174/300
# 250/250 - 1s - loss: 0.0023 - mape: 34.5457 - 1s/epoch - 6ms/step
# Epoch 175/300
# 250/250 - 1s - loss: 0.0020 - mape: 28.5606 - 1s/epoch - 6ms/step
# Epoch 176/300
# 250/250 - 1s - loss: 0.0013 - mape: 29.0096 - 1s/epoch - 6ms/step
# Epoch 177/300
# 250/250 - 1s - loss: 0.0012 - mape: 22.4975 - 1s/epoch - 6ms/step
# Epoch 178/300
# 250/250 - 1s - loss: 7.7806e-04 - mape: 17.3149 - 1s/epoch - 6ms/step
# Epoch 179/300
# 250/250 - 1s - loss: 8.8977e-04 - mape: 23.9977 - 1s/epoch - 6ms/step
# Epoch 180/300
# 250/250 - 1s - loss: 0.0012 - mape: 17.0233 - 1s/epoch - 6ms/step
# Epoch 181/300
# 250/250 - 1s - loss: 0.0015 - mape: 22.9247 - 1s/epoch - 6ms/step
# Epoch 182/300
# 250/250 - 1s - loss: 0.0015 - mape: 30.0040 - 1s/epoch - 6ms/step
# Epoch 183/300
# 250/250 - 1s - loss: 0.0028 - mape: 42.5178 - 1s/epoch - 6ms/step
# Epoch 184/300
# 250/250 - 1s - loss: 0.0022 - mape: 37.7334 - 1s/epoch - 6ms/step
# Epoch 185/300
# 250/250 - 1s - loss: 0.0011 - mape: 24.5638 - 1s/epoch - 6ms/step
# Epoch 186/300
# 250/250 - 1s - loss: 9.5346e-04 - mape: 27.9813 - 1s/epoch - 6ms/step
# Epoch 187/300
# 250/250 - 1s - loss: 5.3972e-04 - mape: 16.3656 - 1s/epoch - 6ms/step
# Epoch 188/300
# 250/250 - 1s - loss: 7.0306e-04 - mape: 18.4414 - 1s/epoch - 6ms/step
# Epoch 189/300
# 250/250 - 1s - loss: 9.6227e-04 - mape: 20.1026 - 1s/epoch - 6ms/step
# Epoch 190/300
# 250/250 - 1s - loss: 0.0012 - mape: 23.8290 - 1s/epoch - 6ms/step
# Epoch 191/300
# 250/250 - 1s - loss: 9.0133e-04 - mape: 20.5223 - 1s/epoch - 6ms/step
# Epoch 192/300
# 250/250 - 1s - loss: 0.0014 - mape: 19.2512 - 1s/epoch - 6ms/step
# Epoch 193/300
# 250/250 - 1s - loss: 0.0011 - mape: 23.9798 - 1s/epoch - 6ms/step
# Epoch 194/300
# 250/250 - 1s - loss: 0.0013 - mape: 26.3510 - 1s/epoch - 6ms/step
# Epoch 195/300
# 250/250 - 1s - loss: 0.0016 - mape: 33.7082 - 1s/epoch - 6ms/step
# Epoch 196/300
# 250/250 - 1s - loss: 0.0019 - mape: 25.7481 - 1s/epoch - 6ms/step
# Epoch 197/300
# 250/250 - 1s - loss: 0.0054 - mape: 71.1863 - 1s/epoch - 6ms/step
# Epoch 198/300
# 250/250 - 1s - loss: 0.0018 - mape: 31.8954 - 1s/epoch - 6ms/step
# Epoch 199/300
# 250/250 - 1s - loss: 7.2437e-04 - mape: 17.2538 - 1s/epoch - 6ms/step
# Epoch 200/300
# 250/250 - 1s - loss: 4.3922e-04 - mape: 14.2150 - 1s/epoch - 6ms/step
# Epoch 201/300
# 250/250 - 1s - loss: 3.3601e-04 - mape: 13.2612 - 1s/epoch - 6ms/step
# Epoch 202/300
# 250/250 - 1s - loss: 2.7168e-04 - mape: 12.8679 - 1s/epoch - 6ms/step
# Epoch 203/300
# 250/250 - 1s - loss: 3.0540e-04 - mape: 10.9706 - 1s/epoch - 6ms/step
# Epoch 204/300
# 250/250 - 1s - loss: 4.4380e-04 - mape: 12.8375 - 1s/epoch - 6ms/step
# Epoch 205/300
# 250/250 - 1s - loss: 0.0011 - mape: 22.3710 - 1s/epoch - 6ms/step
# Epoch 206/300
# 250/250 - 1s - loss: 0.0018 - mape: 24.9215 - 1s/epoch - 6ms/step
# Epoch 207/300
# 250/250 - 1s - loss: 0.0017 - mape: 26.7540 - 1s/epoch - 6ms/step
# Epoch 208/300
# 250/250 - 1s - loss: 0.0029 - mape: 29.4685 - 1s/epoch - 6ms/step
# Epoch 209/300
# 250/250 - 1s - loss: 0.0029 - mape: 39.1262 - 1s/epoch - 6ms/step
# Epoch 210/300
# 250/250 - 1s - loss: 0.0013 - mape: 23.0955 - 1s/epoch - 6ms/step
# Epoch 211/300
# 250/250 - 1s - loss: 6.1220e-04 - mape: 14.6299 - 1s/epoch - 6ms/step
# Epoch 212/300
# 250/250 - 1s - loss: 3.4089e-04 - mape: 13.5611 - 1s/epoch - 6ms/step
# Epoch 213/300
# 250/250 - 1s - loss: 2.6609e-04 - mape: 7.9855 - 1s/epoch - 6ms/step
# Epoch 214/300
# 250/250 - 1s - loss: 4.1525e-04 - mape: 11.1762 - 1s/epoch - 6ms/step
# Epoch 215/300
# 250/250 - 1s - loss: 5.1016e-04 - mape: 14.4378 - 1s/epoch - 6ms/step
# Epoch 216/300
# 250/250 - 1s - loss: 8.0609e-04 - mape: 19.6099 - 1s/epoch - 6ms/step
# Epoch 217/300
# 250/250 - 1s - loss: 0.0016 - mape: 33.0374 - 1s/epoch - 6ms/step
# Epoch 218/300
# 250/250 - 1s - loss: 0.0010 - mape: 22.3747 - 1s/epoch - 6ms/step
# Epoch 219/300
# 250/250 - 1s - loss: 0.0021 - mape: 20.7616 - 1s/epoch - 6ms/step
# Epoch 220/300
# 250/250 - 1s - loss: 0.0076 - mape: 61.1028 - 1s/epoch - 6ms/step
# Epoch 221/300
# 250/250 - 1s - loss: 0.0024 - mape: 42.1259 - 1s/epoch - 6ms/step
# Epoch 222/300
# 250/250 - 1s - loss: 0.0041 - mape: 30.5994 - 1s/epoch - 6ms/step
# Epoch 223/300
# 250/250 - 1s - loss: 8.3654e-04 - mape: 18.7629 - 1s/epoch - 6ms/step
# Epoch 224/300
# 250/250 - 1s - loss: 3.9383e-04 - mape: 14.0129 - 1s/epoch - 6ms/step
# Epoch 225/300
# 250/250 - 1s - loss: 2.0993e-04 - mape: 11.0901 - 1s/epoch - 6ms/step
# Epoch 226/300
# 250/250 - 1s - loss: 1.8213e-04 - mape: 9.5797 - 1s/epoch - 6ms/step
# Epoch 227/300
# 250/250 - 2s - loss: 1.3719e-04 - mape: 8.0844 - 2s/epoch - 7ms/step
# Epoch 228/300
# 250/250 - 2s - loss: 1.2873e-04 - mape: 7.3021 - 2s/epoch - 7ms/step
# Epoch 229/300
# 250/250 - 2s - loss: 1.1933e-04 - mape: 4.9458 - 2s/epoch - 6ms/step
# Epoch 230/300
# 250/250 - 1s - loss: 1.7441e-04 - mape: 7.2406 - 1s/epoch - 6ms/step
# Epoch 231/300
# 250/250 - 1s - loss: 2.6152e-04 - mape: 9.5903 - 1s/epoch - 6ms/step
# Epoch 232/300
# 250/250 - 1s - loss: 7.2811e-04 - mape: 17.7490 - 1s/epoch - 6ms/step
# Epoch 233/300
# 250/250 - 1s - loss: 9.5409e-04 - mape: 26.8026 - 1s/epoch - 6ms/step
# Epoch 234/300
# 250/250 - 1s - loss: 0.0016 - mape: 16.4006 - 1s/epoch - 6ms/step
# Epoch 235/300
# 250/250 - 1s - loss: 0.0014 - mape: 17.5437 - 1s/epoch - 6ms/step
# Epoch 236/300
# 250/250 - 1s - loss: 9.4952e-04 - mape: 20.8643 - 1s/epoch - 6ms/step
# Epoch 237/300
# 250/250 - 1s - loss: 9.9647e-04 - mape: 26.2579 - 1s/epoch - 6ms/step
# Epoch 238/300
# 250/250 - 1s - loss: 0.0010 - mape: 17.3995 - 1s/epoch - 6ms/step
# Epoch 239/300
# 250/250 - 1s - loss: 7.6296e-04 - mape: 16.5941 - 1s/epoch - 6ms/step
# Epoch 240/300
# 250/250 - 1s - loss: 7.4536e-04 - mape: 13.3028 - 1s/epoch - 6ms/step
# Epoch 241/300
# 250/250 - 1s - loss: 7.8246e-04 - mape: 15.3530 - 1s/epoch - 6ms/step
# Epoch 242/300
# 250/250 - 1s - loss: 0.0012 - mape: 21.5758 - 1s/epoch - 6ms/step
# Epoch 243/300
# 250/250 - 1s - loss: 0.0011 - mape: 18.2088 - 1s/epoch - 6ms/step
# Epoch 244/300
# 250/250 - 1s - loss: 0.0010 - mape: 16.7166 - 1s/epoch - 6ms/step
# Epoch 245/300
# 250/250 - 1s - loss: 0.0014 - mape: 19.9089 - 1s/epoch - 6ms/step
# Epoch 246/300
# 250/250 - 1s - loss: 0.0011 - mape: 20.1125 - 1s/epoch - 6ms/step
# Epoch 247/300
# 250/250 - 2s - loss: 0.0010 - mape: 16.9183 - 2s/epoch - 6ms/step
# Epoch 248/300
# 250/250 - 1s - loss: 9.7008e-04 - mape: 18.9664 - 1s/epoch - 6ms/step
# Epoch 249/300
# 250/250 - 1s - loss: 9.3194e-04 - mape: 19.9920 - 1s/epoch - 6ms/step
# Epoch 250/300
# 250/250 - 1s - loss: 8.2024e-04 - mape: 32.2923 - 1s/epoch - 6ms/step
# Epoch 251/300
# 250/250 - 1s - loss: 6.7381e-04 - mape: 27.6294 - 1s/epoch - 6ms/step
# Epoch 252/300
# 250/250 - 1s - loss: 5.6403e-04 - mape: 10.9280 - 1s/epoch - 6ms/step
# Epoch 253/300
# 250/250 - 1s - loss: 4.9005e-04 - mape: 15.0568 - 1s/epoch - 6ms/step
# Epoch 254/300
# 250/250 - 1s - loss: 4.6928e-04 - mape: 23.8607 - 1s/epoch - 6ms/step
# Epoch 255/300
# 250/250 - 1s - loss: 7.4452e-04 - mape: 24.8569 - 1s/epoch - 6ms/step
# Epoch 256/300
# 250/250 - 1s - loss: 0.0013 - mape: 34.1086 - 1s/epoch - 6ms/step
# Epoch 257/300
# 250/250 - 1s - loss: 0.0012 - mape: 16.1151 - 1s/epoch - 6ms/step
# Epoch 258/300
# 250/250 - 1s - loss: 0.0011 - mape: 20.6536 - 1s/epoch - 6ms/step
# Epoch 259/300
# 250/250 - 1s - loss: 0.0012 - mape: 16.8121 - 1s/epoch - 6ms/step
# Epoch 260/300
# 250/250 - 1s - loss: 6.0980e-04 - mape: 21.9881 - 1s/epoch - 6ms/step
# Epoch 261/300
# 250/250 - 1s - loss: 4.6020e-04 - mape: 11.7540 - 1s/epoch - 6ms/step
# Epoch 262/300
# 250/250 - 1s - loss: 4.4231e-04 - mape: 13.3432 - 1s/epoch - 6ms/step
# Epoch 263/300
# 250/250 - 1s - loss: 4.5873e-04 - mape: 23.4486 - 1s/epoch - 6ms/step
# Epoch 264/300
# 250/250 - 1s - loss: 7.3403e-04 - mape: 24.1865 - 1s/epoch - 6ms/step
# Epoch 265/300
# 250/250 - 1s - loss: 0.0013 - mape: 28.8460 - 1s/epoch - 6ms/step
# Epoch 266/300
# 250/250 - 1s - loss: 0.0011 - mape: 17.0214 - 1s/epoch - 6ms/step
# Epoch 267/300
# 250/250 - 1s - loss: 8.1483e-04 - mape: 18.0750 - 1s/epoch - 6ms/step
# Epoch 268/300
# 250/250 - 1s - loss: 0.0014 - mape: 26.5436 - 1s/epoch - 6ms/step
# Epoch 269/300
# 250/250 - 1s - loss: 0.0010 - mape: 13.0198 - 1s/epoch - 6ms/step
# Epoch 270/300
# 250/250 - 1s - loss: 7.7001e-04 - mape: 24.3601 - 1s/epoch - 6ms/step
# Epoch 271/300
# 250/250 - 1s - loss: 6.7801e-04 - mape: 14.1300 - 1s/epoch - 6ms/step
# Epoch 272/300
# 250/250 - 1s - loss: 5.0713e-04 - mape: 11.7353 - 1s/epoch - 6ms/step
# Epoch 273/300
# 250/250 - 1s - loss: 4.7556e-04 - mape: 20.2864 - 1s/epoch - 6ms/step
# Epoch 274/300
# 250/250 - 1s - loss: 5.6829e-04 - mape: 13.7696 - 1s/epoch - 6ms/step
# Epoch 275/300
# 250/250 - 1s - loss: 6.4505e-04 - mape: 20.0615 - 1s/epoch - 6ms/step
# Epoch 276/300
# 250/250 - 1s - loss: 8.0290e-04 - mape: 17.1603 - 1s/epoch - 6ms/step
# Epoch 277/300
# 250/250 - 1s - loss: 0.0025 - mape: 30.3825 - 1s/epoch - 6ms/step
# Epoch 278/300
# 250/250 - 1s - loss: 0.0016 - mape: 33.5972 - 1s/epoch - 6ms/step
# Epoch 279/300
# 250/250 - 1s - loss: 0.0011 - mape: 22.1715 - 1s/epoch - 6ms/step
# Epoch 280/300
# 250/250 - 2s - loss: 5.5199e-04 - mape: 24.6943 - 2s/epoch - 6ms/step
# Epoch 281/300
# 250/250 - 1s - loss: 3.1791e-04 - mape: 12.6063 - 1s/epoch - 6ms/step
# Epoch 282/300
# 250/250 - 1s - loss: 2.3059e-04 - mape: 9.1969 - 1s/epoch - 6ms/step
# Epoch 283/300
# 250/250 - 1s - loss: 2.1907e-04 - mape: 13.7130 - 1s/epoch - 6ms/step
# Epoch 284/300
# 250/250 - 1s - loss: 2.7281e-04 - mape: 10.1315 - 1s/epoch - 6ms/step
# Epoch 285/300
# 250/250 - 1s - loss: 4.0905e-04 - mape: 13.3597 - 1s/epoch - 6ms/step
# Epoch 286/300
# 250/250 - 1s - loss: 7.9208e-04 - mape: 31.4899 - 1s/epoch - 6ms/step
# Epoch 287/300
# 250/250 - 1s - loss: 0.0012 - mape: 23.0093 - 1s/epoch - 6ms/step
# Epoch 288/300
# 250/250 - 1s - loss: 0.0023 - mape: 32.7859 - 1s/epoch - 6ms/step
# Epoch 289/300
# 250/250 - 1s - loss: 0.0017 - mape: 25.7125 - 1s/epoch - 6ms/step
# Epoch 290/300
# 250/250 - 1s - loss: 8.0367e-04 - mape: 15.7912 - 1s/epoch - 6ms/step
# Epoch 291/300
# 250/250 - 1s - loss: 4.0205e-04 - mape: 13.5882 - 1s/epoch - 6ms/step
# Epoch 292/300
# 250/250 - 1s - loss: 2.2394e-04 - mape: 12.9088 - 1s/epoch - 6ms/step
# Epoch 293/300
# 250/250 - 1s - loss: 2.2825e-04 - mape: 10.9154 - 1s/epoch - 6ms/step
# Epoch 294/300
# 250/250 - 1s - loss: 2.6140e-04 - mape: 13.9696 - 1s/epoch - 6ms/step
# Epoch 295/300
# 250/250 - 1s - loss: 3.7406e-04 - mape: 11.0782 - 1s/epoch - 6ms/step
# Epoch 296/300
# 250/250 - 1s - loss: 0.0014 - mape: 21.6965 - 1s/epoch - 6ms/step
# Epoch 297/300
# 250/250 - 1s - loss: 0.0013 - mape: 18.9966 - 1s/epoch - 6ms/step
# Epoch 298/300
# 250/250 - 1s - loss: 8.7309e-04 - mape: 13.3182 - 1s/epoch - 6ms/step
# Epoch 299/300
# 250/250 - 1s - loss: 6.2912e-04 - mape: 13.7919 - 1s/epoch - 6ms/step
# Epoch 300/300
# 250/250 - 1s - loss: 3.9215e-04 - mape: 14.5183 - 1s/epoch - 6ms/step
# 3/3 [==============================] - 1s 6ms/step
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1096151906.py:65: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2761330561.py:2: RuntimeWarning: '<' not supported between instances of 'int' and 'Timestamp', sort order is undefined for incomparable objects.
#   mape = np.mean(np.abs((y - y_pred)/y))*100
# Evaluation for country: Croatia
# Epoch 1/300
# 250/250 - 5s - loss: 0.1078 - mape: 197.8367 - 5s/epoch - 21ms/step
# Epoch 2/300
# 250/250 - 1s - loss: 0.0669 - mape: 158.6961 - 1s/epoch - 6ms/step
# Epoch 3/300
# 250/250 - 1s - loss: 0.0600 - mape: 184.3681 - 1s/epoch - 6ms/step
# Epoch 4/300
# 250/250 - 1s - loss: 0.0578 - mape: 171.9063 - 1s/epoch - 6ms/step
# Epoch 5/300
# 250/250 - 1s - loss: 0.0568 - mape: 177.1051 - 1s/epoch - 6ms/step
# Epoch 6/300
# 250/250 - 1s - loss: 0.0533 - mape: 189.8832 - 1s/epoch - 6ms/step
# Epoch 7/300
# 250/250 - 1s - loss: 0.0536 - mape: 198.4528 - 1s/epoch - 6ms/step
# Epoch 8/300
# 250/250 - 1s - loss: 0.0532 - mape: 189.4500 - 1s/epoch - 6ms/step
# Epoch 9/300
# 250/250 - 1s - loss: 0.0522 - mape: 172.4926 - 1s/epoch - 6ms/step
# Epoch 10/300
# 250/250 - 1s - loss: 0.0523 - mape: 161.1877 - 1s/epoch - 6ms/step
# Epoch 11/300
# 250/250 - 1s - loss: 0.0502 - mape: 124.0908 - 1s/epoch - 6ms/step
# Epoch 12/300
# 250/250 - 1s - loss: 0.0492 - mape: 143.2093 - 1s/epoch - 6ms/step
# Epoch 13/300
# 250/250 - 1s - loss: 0.0502 - mape: 147.3017 - 1s/epoch - 6ms/step
# Epoch 14/300
# 250/250 - 1s - loss: 0.0484 - mape: 139.7917 - 1s/epoch - 6ms/step
# Epoch 15/300
# 250/250 - 1s - loss: 0.0461 - mape: 134.5143 - 1s/epoch - 6ms/step
# Epoch 16/300
# 250/250 - 1s - loss: 0.0484 - mape: 166.0595 - 1s/epoch - 6ms/step
# Epoch 17/300
# 250/250 - 1s - loss: 0.0468 - mape: 134.2949 - 1s/epoch - 6ms/step
# Epoch 18/300
# 250/250 - 1s - loss: 0.0479 - mape: 128.2679 - 1s/epoch - 6ms/step
# Epoch 19/300
# 250/250 - 1s - loss: 0.0468 - mape: 136.9114 - 1s/epoch - 6ms/step
# Epoch 20/300
# 250/250 - 1s - loss: 0.0464 - mape: 137.0238 - 1s/epoch - 6ms/step
# Epoch 21/300
# 250/250 - 1s - loss: 0.0455 - mape: 130.8952 - 1s/epoch - 6ms/step
# Epoch 22/300
# 250/250 - 1s - loss: 0.0459 - mape: 137.7295 - 1s/epoch - 6ms/step
# Epoch 23/300
# 250/250 - 1s - loss: 0.0443 - mape: 114.1231 - 1s/epoch - 6ms/step
# Epoch 24/300
# 250/250 - 1s - loss: 0.0449 - mape: 146.6163 - 1s/epoch - 6ms/step
# Epoch 25/300
# 250/250 - 1s - loss: 0.0448 - mape: 153.0086 - 1s/epoch - 6ms/step
# Epoch 26/300
# 250/250 - 1s - loss: 0.0428 - mape: 128.3739 - 1s/epoch - 6ms/step
# Epoch 27/300
# 250/250 - 2s - loss: 0.0451 - mape: 149.4522 - 2s/epoch - 6ms/step
# Epoch 28/300
# 250/250 - 1s - loss: 0.0442 - mape: 150.7610 - 1s/epoch - 6ms/step
# Epoch 29/300
# 250/250 - 1s - loss: 0.0423 - mape: 125.2793 - 1s/epoch - 6ms/step
# Epoch 30/300
# 250/250 - 1s - loss: 0.0410 - mape: 111.6593 - 1s/epoch - 6ms/step
# Epoch 31/300
# 250/250 - 1s - loss: 0.0411 - mape: 142.6255 - 1s/epoch - 6ms/step
# Epoch 32/300
# 250/250 - 1s - loss: 0.0401 - mape: 131.1911 - 1s/epoch - 6ms/step
# Epoch 33/300
# 250/250 - 1s - loss: 0.0392 - mape: 123.2770 - 1s/epoch - 6ms/step
# Epoch 34/300
# 250/250 - 1s - loss: 0.0399 - mape: 146.5365 - 1s/epoch - 6ms/step
# Epoch 35/300
# 250/250 - 1s - loss: 0.0390 - mape: 99.1386 - 1s/epoch - 6ms/step
# Epoch 36/300
# 250/250 - 1s - loss: 0.0385 - mape: 164.7212 - 1s/epoch - 6ms/step
# Epoch 37/300
# 250/250 - 1s - loss: 0.0395 - mape: 122.2365 - 1s/epoch - 6ms/step
# Epoch 38/300
# 250/250 - 1s - loss: 0.0383 - mape: 138.2153 - 1s/epoch - 6ms/step
# Epoch 39/300
# 250/250 - 1s - loss: 0.0373 - mape: 103.7486 - 1s/epoch - 6ms/step
# Epoch 40/300
# 250/250 - 1s - loss: 0.0362 - mape: 106.0675 - 1s/epoch - 6ms/step
# Epoch 41/300
# 250/250 - 1s - loss: 0.0335 - mape: 127.2583 - 1s/epoch - 6ms/step
# Epoch 42/300
# 250/250 - 1s - loss: 0.0335 - mape: 106.9283 - 1s/epoch - 6ms/step
# Epoch 43/300
# 250/250 - 1s - loss: 0.0357 - mape: 112.2092 - 1s/epoch - 6ms/step
# Epoch 44/300
# 250/250 - 1s - loss: 0.0327 - mape: 119.2013 - 1s/epoch - 6ms/step
# Epoch 45/300
# 250/250 - 1s - loss: 0.0311 - mape: 104.7924 - 1s/epoch - 6ms/step
# Epoch 46/300
# 250/250 - 1s - loss: 0.0312 - mape: 110.9458 - 1s/epoch - 6ms/step
# Epoch 47/300
# 250/250 - 1s - loss: 0.0315 - mape: 108.2525 - 1s/epoch - 6ms/step
# Epoch 48/300
# 250/250 - 1s - loss: 0.0298 - mape: 86.5209 - 1s/epoch - 6ms/step
# Epoch 49/300
# 250/250 - 1s - loss: 0.0293 - mape: 121.0554 - 1s/epoch - 6ms/step
# Epoch 50/300
# 250/250 - 1s - loss: 0.0292 - mape: 110.4780 - 1s/epoch - 6ms/step
# Epoch 51/300
# 250/250 - 1s - loss: 0.0298 - mape: 88.0143 - 1s/epoch - 6ms/step
# Epoch 52/300
# 250/250 - 1s - loss: 0.0301 - mape: 131.5897 - 1s/epoch - 6ms/step
# Epoch 53/300
# 250/250 - 1s - loss: 0.0269 - mape: 115.7944 - 1s/epoch - 6ms/step
# Epoch 54/300
# 250/250 - 1s - loss: 0.0280 - mape: 127.7899 - 1s/epoch - 6ms/step
# Epoch 55/300
# 250/250 - 1s - loss: 0.0261 - mape: 91.9363 - 1s/epoch - 6ms/step
# Epoch 56/300
# 250/250 - 1s - loss: 0.0274 - mape: 102.1247 - 1s/epoch - 6ms/step
# Epoch 57/300
# 250/250 - 1s - loss: 0.0242 - mape: 87.2076 - 1s/epoch - 6ms/step
# Epoch 58/300
# 250/250 - 1s - loss: 0.0262 - mape: 132.0528 - 1s/epoch - 6ms/step
# Epoch 59/300
# 250/250 - 1s - loss: 0.0253 - mape: 110.6411 - 1s/epoch - 6ms/step
# Epoch 60/300
# 250/250 - 1s - loss: 0.0234 - mape: 86.3315 - 1s/epoch - 6ms/step
# Epoch 61/300
# 250/250 - 1s - loss: 0.0234 - mape: 98.2908 - 1s/epoch - 6ms/step
# Epoch 62/300
# 250/250 - 2s - loss: 0.0228 - mape: 124.8247 - 2s/epoch - 6ms/step
# Epoch 63/300
# 250/250 - 2s - loss: 0.0238 - mape: 92.2238 - 2s/epoch - 6ms/step
# Epoch 64/300
# 250/250 - 2s - loss: 0.0225 - mape: 100.8326 - 2s/epoch - 6ms/step
# Epoch 65/300
# 250/250 - 2s - loss: 0.0219 - mape: 93.9788 - 2s/epoch - 7ms/step
# Epoch 66/300
# 250/250 - 2s - loss: 0.0234 - mape: 119.9170 - 2s/epoch - 8ms/step
# Epoch 67/300
# 250/250 - 2s - loss: 0.0225 - mape: 99.1160 - 2s/epoch - 7ms/step
# Epoch 68/300
# 250/250 - 2s - loss: 0.0221 - mape: 84.6243 - 2s/epoch - 7ms/step
# Epoch 69/300
# 250/250 - 2s - loss: 0.0222 - mape: 108.8633 - 2s/epoch - 7ms/step
# Epoch 70/300
# 250/250 - 2s - loss: 0.0219 - mape: 78.6340 - 2s/epoch - 7ms/step
# Epoch 71/300
# 250/250 - 2s - loss: 0.0207 - mape: 95.5025 - 2s/epoch - 7ms/step
# Epoch 72/300
# 250/250 - 2s - loss: 0.0206 - mape: 104.7718 - 2s/epoch - 7ms/step
# Epoch 73/300
# 250/250 - 2s - loss: 0.0193 - mape: 70.0970 - 2s/epoch - 7ms/step
# Epoch 74/300
# 250/250 - 2s - loss: 0.0191 - mape: 77.8455 - 2s/epoch - 7ms/step
# Epoch 75/300
# 250/250 - 2s - loss: 0.0193 - mape: 115.6504 - 2s/epoch - 7ms/step
# Epoch 76/300
# 250/250 - 2s - loss: 0.0182 - mape: 79.7020 - 2s/epoch - 7ms/step
# Epoch 77/300
# 250/250 - 2s - loss: 0.0170 - mape: 83.3826 - 2s/epoch - 7ms/step
# Epoch 78/300
# 250/250 - 2s - loss: 0.0177 - mape: 85.7167 - 2s/epoch - 7ms/step
# Epoch 79/300
# 250/250 - 2s - loss: 0.0184 - mape: 100.5971 - 2s/epoch - 7ms/step
# Epoch 80/300
# 250/250 - 1s - loss: 0.0195 - mape: 105.4822 - 1s/epoch - 6ms/step
# Epoch 81/300
# 250/250 - 1s - loss: 0.0184 - mape: 76.7518 - 1s/epoch - 6ms/step
# Epoch 82/300
# 250/250 - 1s - loss: 0.0159 - mape: 85.9090 - 1s/epoch - 6ms/step
# Epoch 83/300
# 250/250 - 1s - loss: 0.0163 - mape: 84.7474 - 1s/epoch - 6ms/step
# Epoch 84/300
# 250/250 - 1s - loss: 0.0169 - mape: 107.9885 - 1s/epoch - 6ms/step
# Epoch 85/300
# 250/250 - 1s - loss: 0.0158 - mape: 82.1418 - 1s/epoch - 6ms/step
# Epoch 86/300
# 250/250 - 1s - loss: 0.0193 - mape: 99.4444 - 1s/epoch - 6ms/step
# Epoch 87/300
# 250/250 - 1s - loss: 0.0165 - mape: 85.8870 - 1s/epoch - 6ms/step
# Epoch 88/300
# 250/250 - 1s - loss: 0.0155 - mape: 73.9911 - 1s/epoch - 6ms/step
# Epoch 89/300
# 250/250 - 1s - loss: 0.0152 - mape: 64.0521 - 1s/epoch - 6ms/step
# Epoch 90/300
# 250/250 - 1s - loss: 0.0147 - mape: 70.4013 - 1s/epoch - 6ms/step
# Epoch 91/300
# 250/250 - 1s - loss: 0.0134 - mape: 69.2886 - 1s/epoch - 6ms/step
# Epoch 92/300
# 250/250 - 1s - loss: 0.0163 - mape: 73.8986 - 1s/epoch - 6ms/step
# Epoch 93/300
# 250/250 - 1s - loss: 0.0170 - mape: 89.5014 - 1s/epoch - 6ms/step
# Epoch 94/300
# 250/250 - 1s - loss: 0.0142 - mape: 75.6116 - 1s/epoch - 6ms/step
# Epoch 95/300
# 250/250 - 2s - loss: 0.0134 - mape: 75.8579 - 2s/epoch - 6ms/step
# Epoch 96/300
# 250/250 - 2s - loss: 0.0135 - mape: 79.3118 - 2s/epoch - 6ms/step
# Epoch 97/300
# 250/250 - 1s - loss: 0.0136 - mape: 82.9447 - 1s/epoch - 6ms/step
# Epoch 98/300
# 250/250 - 1s - loss: 0.0143 - mape: 108.7488 - 1s/epoch - 6ms/step
# Epoch 99/300
# 250/250 - 1s - loss: 0.0125 - mape: 98.7071 - 1s/epoch - 6ms/step
# Epoch 100/300
# 250/250 - 1s - loss: 0.0118 - mape: 62.2652 - 1s/epoch - 6ms/step
# Epoch 101/300
# 250/250 - 1s - loss: 0.0133 - mape: 72.8068 - 1s/epoch - 6ms/step
# Epoch 102/300
# 250/250 - 2s - loss: 0.0127 - mape: 86.7350 - 2s/epoch - 6ms/step
# Epoch 103/300
# 250/250 - 1s - loss: 0.0131 - mape: 82.8587 - 1s/epoch - 6ms/step
# Epoch 104/300
# 250/250 - 1s - loss: 0.0136 - mape: 95.4695 - 1s/epoch - 6ms/step
# Epoch 105/300
# 250/250 - 1s - loss: 0.0134 - mape: 104.4928 - 1s/epoch - 6ms/step
# Epoch 106/300
# 250/250 - 1s - loss: 0.0124 - mape: 73.3197 - 1s/epoch - 6ms/step
# Epoch 107/300
# 250/250 - 1s - loss: 0.0116 - mape: 58.0259 - 1s/epoch - 6ms/step
# Epoch 108/300
# 250/250 - 2s - loss: 0.0103 - mape: 54.2290 - 2s/epoch - 6ms/step
# Epoch 109/300
# 250/250 - 1s - loss: 0.0104 - mape: 59.1638 - 1s/epoch - 6ms/step
# Epoch 110/300
# 250/250 - 1s - loss: 0.0102 - mape: 59.4690 - 1s/epoch - 6ms/step
# Epoch 111/300
# 250/250 - 1s - loss: 0.0109 - mape: 84.7943 - 1s/epoch - 6ms/step
# Epoch 112/300
# 250/250 - 1s - loss: 0.0103 - mape: 55.9334 - 1s/epoch - 6ms/step
# Epoch 113/300
# 250/250 - 1s - loss: 0.0108 - mape: 81.7719 - 1s/epoch - 6ms/step
# Epoch 114/300
# 250/250 - 1s - loss: 0.0103 - mape: 61.1893 - 1s/epoch - 6ms/step
# Epoch 115/300
# 250/250 - 1s - loss: 0.0118 - mape: 66.6048 - 1s/epoch - 6ms/step
# Epoch 116/300
# 250/250 - 1s - loss: 0.0099 - mape: 49.5075 - 1s/epoch - 6ms/step
# Epoch 117/300
# 250/250 - 1s - loss: 0.0095 - mape: 66.8350 - 1s/epoch - 6ms/step
# Epoch 118/300
# 250/250 - 1s - loss: 0.0087 - mape: 53.5190 - 1s/epoch - 6ms/step
# Epoch 119/300
# 250/250 - 1s - loss: 0.0100 - mape: 56.9716 - 1s/epoch - 6ms/step
# Epoch 120/300
# 250/250 - 1s - loss: 0.0107 - mape: 70.6933 - 1s/epoch - 6ms/step
# Epoch 121/300
# 250/250 - 1s - loss: 0.0073 - mape: 50.1761 - 1s/epoch - 6ms/step
# Epoch 122/300
# 250/250 - 1s - loss: 0.0072 - mape: 44.4044 - 1s/epoch - 6ms/step
# Epoch 123/300
# 250/250 - 1s - loss: 0.0060 - mape: 49.4522 - 1s/epoch - 6ms/step
# Epoch 124/300
# 250/250 - 2s - loss: 0.0063 - mape: 45.7305 - 2s/epoch - 6ms/step
# Epoch 125/300
# 250/250 - 2s - loss: 0.0068 - mape: 50.1001 - 2s/epoch - 6ms/step
# Epoch 126/300
# 250/250 - 2s - loss: 0.0061 - mape: 80.4385 - 2s/epoch - 7ms/step
# Epoch 127/300
# 250/250 - 1s - loss: 0.0068 - mape: 76.6488 - 1s/epoch - 6ms/step
# Epoch 128/300
# 250/250 - 1s - loss: 0.0071 - mape: 67.5801 - 1s/epoch - 6ms/step
# Epoch 129/300
# 250/250 - 1s - loss: 0.0054 - mape: 46.4980 - 1s/epoch - 6ms/step
# Epoch 130/300
# 250/250 - 1s - loss: 0.0056 - mape: 41.1602 - 1s/epoch - 6ms/step
# Epoch 131/300
# 250/250 - 1s - loss: 0.0074 - mape: 40.1389 - 1s/epoch - 6ms/step
# Epoch 132/300
# 250/250 - 1s - loss: 0.0066 - mape: 48.5446 - 1s/epoch - 6ms/step
# Epoch 133/300
# 250/250 - 1s - loss: 0.0046 - mape: 42.0115 - 1s/epoch - 6ms/step
# Epoch 134/300
# 250/250 - 1s - loss: 0.0042 - mape: 57.5923 - 1s/epoch - 6ms/step
# Epoch 135/300
# 250/250 - 1s - loss: 0.0035 - mape: 47.9648 - 1s/epoch - 6ms/step
# Epoch 136/300
# 250/250 - 1s - loss: 0.0049 - mape: 33.0465 - 1s/epoch - 6ms/step
# Epoch 137/300
# 250/250 - 1s - loss: 0.0035 - mape: 39.1406 - 1s/epoch - 6ms/step
# Epoch 138/300
# 250/250 - 1s - loss: 0.0044 - mape: 57.8524 - 1s/epoch - 6ms/step
# Epoch 139/300
# 250/250 - 1s - loss: 0.0050 - mape: 79.6485 - 1s/epoch - 6ms/step
# Epoch 140/300
# 250/250 - 1s - loss: 0.0055 - mape: 57.8851 - 1s/epoch - 6ms/step
# Epoch 141/300
# 250/250 - 1s - loss: 0.0054 - mape: 54.7272 - 1s/epoch - 6ms/step
# Epoch 142/300
# 250/250 - 1s - loss: 0.0049 - mape: 47.3409 - 1s/epoch - 6ms/step
# Epoch 143/300
# 250/250 - 2s - loss: 0.0038 - mape: 41.1926 - 2s/epoch - 6ms/step
# Epoch 144/300
# 250/250 - 1s - loss: 0.0028 - mape: 32.3757 - 1s/epoch - 6ms/step
# Epoch 145/300
# 250/250 - 1s - loss: 0.0037 - mape: 41.9340 - 1s/epoch - 6ms/step
# Epoch 146/300
# 250/250 - 1s - loss: 0.0050 - mape: 41.0595 - 1s/epoch - 6ms/step
# Epoch 147/300
# 250/250 - 1s - loss: 0.0024 - mape: 31.5762 - 1s/epoch - 6ms/step
# Epoch 148/300
# 250/250 - 1s - loss: 0.0018 - mape: 32.1944 - 1s/epoch - 6ms/step
# Epoch 149/300
# 250/250 - 1s - loss: 0.0014 - mape: 23.1295 - 1s/epoch - 6ms/step
# Epoch 150/300
# 250/250 - 1s - loss: 0.0031 - mape: 27.9615 - 1s/epoch - 6ms/step
# Epoch 151/300
# 250/250 - 1s - loss: 0.0035 - mape: 46.3084 - 1s/epoch - 6ms/step
# Epoch 152/300
# 250/250 - 1s - loss: 0.0030 - mape: 37.5775 - 1s/epoch - 6ms/step
# Epoch 153/300
# 250/250 - 1s - loss: 0.0027 - mape: 30.4294 - 1s/epoch - 6ms/step
# Epoch 154/300
# 250/250 - 1s - loss: 0.0025 - mape: 37.0299 - 1s/epoch - 6ms/step
# Epoch 155/300
# 250/250 - 1s - loss: 0.0019 - mape: 22.1293 - 1s/epoch - 6ms/step
# Epoch 156/300
# 250/250 - 1s - loss: 0.0017 - mape: 32.3049 - 1s/epoch - 6ms/step
# Epoch 157/300
# 250/250 - 1s - loss: 0.0015 - mape: 19.8125 - 1s/epoch - 6ms/step
# Epoch 158/300
# 250/250 - 1s - loss: 0.0023 - mape: 33.5601 - 1s/epoch - 6ms/step
# Epoch 159/300
# 250/250 - 1s - loss: 0.0021 - mape: 24.7495 - 1s/epoch - 6ms/step
# Epoch 160/300
# 250/250 - 1s - loss: 0.0029 - mape: 38.9746 - 1s/epoch - 6ms/step
# Epoch 161/300
# 250/250 - 1s - loss: 0.0035 - mape: 31.1322 - 1s/epoch - 6ms/step
# Epoch 162/300
# 250/250 - 1s - loss: 0.0029 - mape: 33.7062 - 1s/epoch - 6ms/step
# Epoch 163/300
# 250/250 - 1s - loss: 0.0035 - mape: 32.8338 - 1s/epoch - 6ms/step
# Epoch 164/300
# 250/250 - 1s - loss: 0.0014 - mape: 28.1066 - 1s/epoch - 6ms/step
# Epoch 165/300
# 250/250 - 1s - loss: 0.0021 - mape: 26.0397 - 1s/epoch - 6ms/step
# Epoch 166/300
# 250/250 - 1s - loss: 0.0013 - mape: 31.8896 - 1s/epoch - 6ms/step
# Epoch 167/300
# 250/250 - 1s - loss: 0.0018 - mape: 23.1689 - 1s/epoch - 6ms/step
# Epoch 168/300
# 250/250 - 1s - loss: 0.0021 - mape: 34.4711 - 1s/epoch - 6ms/step
# Epoch 169/300
# 250/250 - 1s - loss: 0.0025 - mape: 30.2802 - 1s/epoch - 6ms/step
# Epoch 170/300
# 250/250 - 1s - loss: 0.0026 - mape: 39.4485 - 1s/epoch - 6ms/step
# Epoch 171/300
# 250/250 - 1s - loss: 0.0018 - mape: 24.6510 - 1s/epoch - 6ms/step
# Epoch 172/300
# 250/250 - 1s - loss: 0.0016 - mape: 22.3741 - 1s/epoch - 6ms/step
# Epoch 173/300
# 250/250 - 1s - loss: 0.0015 - mape: 22.8691 - 1s/epoch - 6ms/step
# Epoch 174/300
# 250/250 - 1s - loss: 0.0019 - mape: 31.0427 - 1s/epoch - 6ms/step
# Epoch 175/300
# 250/250 - 1s - loss: 0.0018 - mape: 27.0000 - 1s/epoch - 6ms/step
# Epoch 176/300
# 250/250 - 1s - loss: 0.0019 - mape: 26.6200 - 1s/epoch - 6ms/step
# Epoch 177/300
# 250/250 - 1s - loss: 0.0022 - mape: 36.3657 - 1s/epoch - 6ms/step
# Epoch 178/300
# 250/250 - 1s - loss: 0.0017 - mape: 31.0279 - 1s/epoch - 6ms/step
# Epoch 179/300
# 250/250 - 1s - loss: 0.0017 - mape: 38.4561 - 1s/epoch - 6ms/step
# Epoch 180/300
# 250/250 - 1s - loss: 0.0021 - mape: 56.2292 - 1s/epoch - 6ms/step
# Epoch 181/300
# 250/250 - 1s - loss: 0.0032 - mape: 32.6609 - 1s/epoch - 6ms/step
# Epoch 182/300
# 250/250 - 1s - loss: 0.0021 - mape: 27.3590 - 1s/epoch - 6ms/step
# Epoch 183/300
# 250/250 - 1s - loss: 0.0013 - mape: 30.4958 - 1s/epoch - 6ms/step
# Epoch 184/300
# 250/250 - 1s - loss: 0.0015 - mape: 20.9387 - 1s/epoch - 6ms/step
# Epoch 185/300
# 250/250 - 1s - loss: 0.0014 - mape: 21.4286 - 1s/epoch - 6ms/step
# Epoch 186/300
# 250/250 - 1s - loss: 0.0015 - mape: 27.3349 - 1s/epoch - 6ms/step
# Epoch 187/300
# 250/250 - 1s - loss: 0.0020 - mape: 27.7211 - 1s/epoch - 6ms/step
# Epoch 188/300
# 250/250 - 1s - loss: 0.0016 - mape: 26.9946 - 1s/epoch - 6ms/step
# Epoch 189/300
# 250/250 - 1s - loss: 0.0010 - mape: 26.2706 - 1s/epoch - 6ms/step
# Epoch 190/300
# 250/250 - 1s - loss: 0.0011 - mape: 37.7115 - 1s/epoch - 6ms/step
# Epoch 191/300
# 250/250 - 2s - loss: 0.0011 - mape: 29.2095 - 2s/epoch - 6ms/step
# Epoch 192/300
# 250/250 - 1s - loss: 0.0013 - mape: 40.9757 - 1s/epoch - 6ms/step
# Epoch 193/300
# 250/250 - 1s - loss: 0.0017 - mape: 46.9874 - 1s/epoch - 6ms/step
# Epoch 194/300
# 250/250 - 1s - loss: 0.0097 - mape: 42.7128 - 1s/epoch - 6ms/step
# Epoch 195/300
# 250/250 - 1s - loss: 0.0058 - mape: 38.3704 - 1s/epoch - 6ms/step
# Epoch 196/300
# 250/250 - 1s - loss: 0.0042 - mape: 48.8214 - 1s/epoch - 6ms/step
# Epoch 197/300
# 250/250 - 1s - loss: 0.0011 - mape: 27.8084 - 1s/epoch - 6ms/step
# Epoch 198/300
# 250/250 - 1s - loss: 5.4375e-04 - mape: 15.8974 - 1s/epoch - 6ms/step
# Epoch 199/300
# 250/250 - 1s - loss: 2.5887e-04 - mape: 15.9990 - 1s/epoch - 6ms/step
# Epoch 200/300
# 250/250 - 1s - loss: 2.0307e-04 - mape: 11.9914 - 1s/epoch - 6ms/step
# Epoch 201/300
# 250/250 - 1s - loss: 1.5052e-04 - mape: 11.6421 - 1s/epoch - 6ms/step
# Epoch 202/300
# 250/250 - 1s - loss: 1.1613e-04 - mape: 8.3731 - 1s/epoch - 6ms/step
# Epoch 203/300
# 250/250 - 1s - loss: 1.4410e-04 - mape: 14.7290 - 1s/epoch - 6ms/step
# Epoch 204/300
# 250/250 - 1s - loss: 3.2115e-04 - mape: 15.7662 - 1s/epoch - 6ms/step
# Epoch 205/300
# 250/250 - 1s - loss: 6.4803e-04 - mape: 19.1612 - 1s/epoch - 6ms/step
# Epoch 206/300
# 250/250 - 1s - loss: 0.0024 - mape: 28.8247 - 1s/epoch - 6ms/step
# Epoch 207/300
# 250/250 - 1s - loss: 0.0071 - mape: 38.2349 - 1s/epoch - 6ms/step
# Epoch 208/300
# 250/250 - 1s - loss: 0.0043 - mape: 42.6064 - 1s/epoch - 6ms/step
# Epoch 209/300
# 250/250 - 1s - loss: 0.0013 - mape: 38.8790 - 1s/epoch - 6ms/step
# Epoch 210/300
# 250/250 - 1s - loss: 5.7392e-04 - mape: 17.8510 - 1s/epoch - 6ms/step
# Epoch 211/300
# 250/250 - 1s - loss: 4.1579e-04 - mape: 14.1537 - 1s/epoch - 6ms/step
# Epoch 212/300
# 250/250 - 1s - loss: 3.2686e-04 - mape: 13.7775 - 1s/epoch - 6ms/step
# Epoch 213/300
# 250/250 - 1s - loss: 3.6793e-04 - mape: 17.5887 - 1s/epoch - 6ms/step
# Epoch 214/300
# 250/250 - 1s - loss: 4.2422e-04 - mape: 19.1301 - 1s/epoch - 6ms/step
# Epoch 215/300
# 250/250 - 1s - loss: 6.3767e-04 - mape: 13.5282 - 1s/epoch - 6ms/step
# Epoch 216/300
# 250/250 - 1s - loss: 0.0014 - mape: 24.6283 - 1s/epoch - 6ms/step
# Epoch 217/300
# 250/250 - 1s - loss: 0.0158 - mape: 60.0649 - 1s/epoch - 6ms/step
# Epoch 218/300
# 250/250 - 1s - loss: 0.0043 - mape: 42.3827 - 1s/epoch - 6ms/step
# Epoch 219/300
# 250/250 - 1s - loss: 9.3057e-04 - mape: 19.9673 - 1s/epoch - 6ms/step
# Epoch 220/300
# 250/250 - 1s - loss: 5.0481e-04 - mape: 18.4419 - 1s/epoch - 6ms/step
# Epoch 221/300
# 250/250 - 1s - loss: 2.4845e-04 - mape: 11.3026 - 1s/epoch - 6ms/step
# Epoch 222/300
# 250/250 - 1s - loss: 1.8193e-04 - mape: 11.0978 - 1s/epoch - 6ms/step
# Epoch 223/300
# 250/250 - 1s - loss: 1.2228e-04 - mape: 9.0560 - 1s/epoch - 6ms/step
# Epoch 224/300
# 250/250 - 1s - loss: 1.0737e-04 - mape: 5.5231 - 1s/epoch - 6ms/step
# Epoch 225/300
# 250/250 - 1s - loss: 1.5688e-04 - mape: 10.8822 - 1s/epoch - 6ms/step
# Epoch 226/300
# 250/250 - 1s - loss: 2.6500e-04 - mape: 13.5604 - 1s/epoch - 6ms/step
# Epoch 227/300
# 250/250 - 1s - loss: 8.7226e-04 - mape: 19.0181 - 1s/epoch - 6ms/step
# Epoch 228/300
# 250/250 - 2s - loss: 0.0016 - mape: 51.5923 - 2s/epoch - 6ms/step
# Epoch 229/300
# 250/250 - 2s - loss: 0.0026 - mape: 73.1207 - 2s/epoch - 6ms/step
# Epoch 230/300
# 250/250 - 1s - loss: 0.0032 - mape: 41.6049 - 1s/epoch - 6ms/step
# Epoch 231/300
# 250/250 - 1s - loss: 0.0016 - mape: 25.3580 - 1s/epoch - 6ms/step
# Epoch 232/300
# 250/250 - 1s - loss: 9.7736e-04 - mape: 16.5597 - 1s/epoch - 6ms/step
# Epoch 233/300
# 250/250 - 1s - loss: 6.7191e-04 - mape: 20.0837 - 1s/epoch - 6ms/step
# Epoch 234/300
# 250/250 - 1s - loss: 4.5676e-04 - mape: 17.7681 - 1s/epoch - 6ms/step
# Epoch 235/300
# 250/250 - 1s - loss: 6.6543e-04 - mape: 13.6007 - 1s/epoch - 6ms/step
# Epoch 236/300
# 250/250 - 1s - loss: 6.1634e-04 - mape: 13.2929 - 1s/epoch - 6ms/step
# Epoch 237/300
# 250/250 - 1s - loss: 6.1929e-04 - mape: 26.6485 - 1s/epoch - 6ms/step
# Epoch 238/300
# 250/250 - 1s - loss: 8.2561e-04 - mape: 23.7373 - 1s/epoch - 6ms/step
# Epoch 239/300
# 250/250 - 1s - loss: 0.0018 - mape: 28.0505 - 1s/epoch - 6ms/step
# Epoch 240/300
# 250/250 - 1s - loss: 0.0024 - mape: 46.6028 - 1s/epoch - 6ms/step
# Epoch 241/300
# 250/250 - 1s - loss: 0.0032 - mape: 32.1374 - 1s/epoch - 6ms/step
# Epoch 242/300
# 250/250 - 1s - loss: 0.0019 - mape: 28.0079 - 1s/epoch - 6ms/step
# Epoch 243/300
# 250/250 - 1s - loss: 0.0011 - mape: 31.6481 - 1s/epoch - 6ms/step
# Epoch 244/300
# 250/250 - 1s - loss: 6.0293e-04 - mape: 21.4726 - 1s/epoch - 6ms/step
# Epoch 245/300
# 250/250 - 1s - loss: 4.4889e-04 - mape: 12.1790 - 1s/epoch - 6ms/step
# Epoch 246/300
# 250/250 - 1s - loss: 5.0474e-04 - mape: 25.2844 - 1s/epoch - 6ms/step
# Epoch 247/300
# 250/250 - 1s - loss: 8.0741e-04 - mape: 19.1890 - 1s/epoch - 6ms/step
# Epoch 248/300
# 250/250 - 1s - loss: 9.8968e-04 - mape: 28.0717 - 1s/epoch - 6ms/step
# Epoch 249/300
# 250/250 - 1s - loss: 0.0022 - mape: 30.4770 - 1s/epoch - 6ms/step
# Epoch 250/300
# 250/250 - 1s - loss: 0.0075 - mape: 46.5377 - 1s/epoch - 6ms/step
# Epoch 251/300
# 250/250 - 1s - loss: 0.0028 - mape: 36.6493 - 1s/epoch - 6ms/step
# Epoch 252/300
# 250/250 - 1s - loss: 8.2726e-04 - mape: 20.6821 - 1s/epoch - 6ms/step
# Epoch 253/300
# 250/250 - 1s - loss: 3.7025e-04 - mape: 14.3658 - 1s/epoch - 6ms/step
# Epoch 254/300
# 250/250 - 1s - loss: 2.9133e-04 - mape: 11.1615 - 1s/epoch - 6ms/step
# Epoch 255/300
# 250/250 - 1s - loss: 1.7528e-04 - mape: 14.4583 - 1s/epoch - 6ms/step
# Epoch 256/300
# 250/250 - 1s - loss: 1.9568e-04 - mape: 12.6016 - 1s/epoch - 6ms/step
# Epoch 257/300
# 250/250 - 1s - loss: 1.6298e-04 - mape: 8.1585 - 1s/epoch - 6ms/step
# Epoch 258/300
# 250/250 - 1s - loss: 2.8185e-04 - mape: 9.2120 - 1s/epoch - 6ms/step
# Epoch 259/300
# 250/250 - 1s - loss: 5.6456e-04 - mape: 16.1707 - 1s/epoch - 6ms/step
# Epoch 260/300
# 250/250 - 1s - loss: 0.0014 - mape: 15.0991 - 1s/epoch - 6ms/step
# Epoch 261/300
# 250/250 - 1s - loss: 0.0022 - mape: 32.3073 - 1s/epoch - 6ms/step
# Epoch 262/300
# 250/250 - 1s - loss: 0.0017 - mape: 25.3467 - 1s/epoch - 6ms/step
# Epoch 263/300
# 250/250 - 1s - loss: 0.0015 - mape: 31.6037 - 1s/epoch - 6ms/step
# Epoch 264/300
# 250/250 - 1s - loss: 9.6396e-04 - mape: 25.1739 - 1s/epoch - 6ms/step
# Epoch 265/300
# 250/250 - 1s - loss: 6.8584e-04 - mape: 26.2311 - 1s/epoch - 6ms/step
# Epoch 266/300
# 250/250 - 1s - loss: 0.0012 - mape: 28.0276 - 1s/epoch - 6ms/step
# Epoch 267/300
# 250/250 - 1s - loss: 0.0010 - mape: 24.9148 - 1s/epoch - 6ms/step
# Epoch 268/300
# 250/250 - 1s - loss: 7.8458e-04 - mape: 25.2255 - 1s/epoch - 6ms/step
# Epoch 269/300
# 250/250 - 1s - loss: 5.2011e-04 - mape: 23.1391 - 1s/epoch - 6ms/step
# Epoch 270/300
# 250/250 - 1s - loss: 5.1677e-04 - mape: 12.6172 - 1s/epoch - 6ms/step
# Epoch 271/300
# 250/250 - 2s - loss: 0.0010 - mape: 20.2671 - 2s/epoch - 6ms/step
# Epoch 272/300
# 250/250 - 2s - loss: 9.2107e-04 - mape: 17.4750 - 2s/epoch - 6ms/step
# Epoch 273/300
# 250/250 - 1s - loss: 9.9717e-04 - mape: 24.1344 - 1s/epoch - 6ms/step
# Epoch 274/300
# 250/250 - 1s - loss: 0.0012 - mape: 38.5601 - 1s/epoch - 6ms/step
# Epoch 275/300
# 250/250 - 2s - loss: 0.0020 - mape: 29.5266 - 2s/epoch - 6ms/step
# Epoch 276/300
# 250/250 - 1s - loss: 0.0012 - mape: 17.2992 - 1s/epoch - 6ms/step
# Epoch 277/300
# 250/250 - 1s - loss: 7.1377e-04 - mape: 15.9252 - 1s/epoch - 6ms/step
# Epoch 278/300
# 250/250 - 1s - loss: 5.9742e-04 - mape: 18.9355 - 1s/epoch - 6ms/step
# Epoch 279/300
# 250/250 - 1s - loss: 4.0603e-04 - mape: 17.4018 - 1s/epoch - 6ms/step
# Epoch 280/300
# 250/250 - 1s - loss: 6.5728e-04 - mape: 14.3770 - 1s/epoch - 6ms/step
# Epoch 281/300
# 250/250 - 1s - loss: 9.9350e-04 - mape: 14.6315 - 1s/epoch - 6ms/step
# Epoch 282/300
# 250/250 - 1s - loss: 0.0012 - mape: 20.4966 - 1s/epoch - 6ms/step
# Epoch 283/300
# 250/250 - 1s - loss: 0.0014 - mape: 27.8484 - 1s/epoch - 6ms/step
# Epoch 284/300
# 250/250 - 1s - loss: 0.0012 - mape: 20.3563 - 1s/epoch - 6ms/step
# Epoch 285/300
# 250/250 - 1s - loss: 8.5528e-04 - mape: 17.2580 - 1s/epoch - 6ms/step
# Epoch 286/300
# 250/250 - 1s - loss: 6.6941e-04 - mape: 21.6189 - 1s/epoch - 6ms/step
# Epoch 287/300
# 250/250 - 1s - loss: 7.9705e-04 - mape: 25.5935 - 1s/epoch - 6ms/step
# Epoch 288/300
# ...
# 250/250 - 1s - loss: 0.0062 - mape: 148.7625 - 1s/epoch - 6ms/step
# Epoch 110/300
# 250/250 - 1s - loss: 0.0052 - mape: 128.1896 - 1s/epoch - 6ms/step
# Epoch 111/300
# 250/250 - 1s - loss: 0.0067 - mape: 87.2052 - 1s/epoch - 6ms/step
# Epoch 112/300
# 250/250 - 1s - loss: 0.0062 - mape: 153.7359 - 1s/epoch - 6ms/step
# Epoch 113/300
# 250/250 - 1s - loss: 0.0061 - mape: 97.6687 - 1s/epoch - 6ms/step
# Epoch 114/300
# 250/250 - 1s - loss: 0.0053 - mape: 134.1055 - 1s/epoch - 6ms/step
# Epoch 115/300
# 250/250 - 1s - loss: 0.0049 - mape: 47.5474 - 1s/epoch - 6ms/step
# Epoch 116/300
# 250/250 - 1s - loss: 0.0048 - mape: 136.5790 - 1s/epoch - 6ms/step
# Epoch 117/300
# 250/250 - 1s - loss: 0.0052 - mape: 69.4651 - 1s/epoch - 6ms/step
# Epoch 118/300
# 250/250 - 1s - loss: 0.0055 - mape: 112.1775 - 1s/epoch - 6ms/step
# Epoch 119/300
# 250/250 - 1s - loss: 0.0056 - mape: 66.0839 - 1s/epoch - 6ms/step
# Epoch 120/300
# 250/250 - 1s - loss: 0.0049 - mape: 68.0919 - 1s/epoch - 6ms/step
# Epoch 121/300
# 250/250 - 1s - loss: 0.0046 - mape: 79.0336 - 1s/epoch - 6ms/step
# Epoch 122/300
# 250/250 - 1s - loss: 0.0043 - mape: 37.2914 - 1s/epoch - 6ms/step
# Epoch 123/300
# 250/250 - 1s - loss: 0.0052 - mape: 136.7720 - 1s/epoch - 6ms/step
# Epoch 124/300
# 250/250 - 1s - loss: 0.0052 - mape: 36.7716 - 1s/epoch - 6ms/step
# Epoch 125/300
# 250/250 - 1s - loss: 0.0043 - mape: 30.3586 - 1s/epoch - 6ms/step
# Epoch 126/300
# 250/250 - 1s - loss: 0.0048 - mape: 33.6284 - 1s/epoch - 6ms/step
# Epoch 127/300
# 250/250 - 1s - loss: 0.0042 - mape: 91.1893 - 1s/epoch - 6ms/step
# Epoch 128/300
# 250/250 - 1s - loss: 0.0046 - mape: 48.1166 - 1s/epoch - 6ms/step
# Epoch 129/300
# 250/250 - 2s - loss: 0.0045 - mape: 46.4808 - 2s/epoch - 6ms/step
# Epoch 130/300
# 250/250 - 1s - loss: 0.0039 - mape: 72.7596 - 1s/epoch - 6ms/step
# Epoch 131/300
# 250/250 - 1s - loss: 0.0041 - mape: 49.2922 - 1s/epoch - 6ms/step
# Epoch 132/300
# 250/250 - 1s - loss: 0.0082 - mape: 236.9631 - 1s/epoch - 6ms/step
# Epoch 133/300
# 250/250 - 1s - loss: 0.0057 - mape: 88.5098 - 1s/epoch - 6ms/step
# Epoch 134/300
# 250/250 - 1s - loss: 0.0042 - mape: 65.1529 - 1s/epoch - 6ms/step
# Epoch 135/300
# 250/250 - 1s - loss: 0.0035 - mape: 28.0795 - 1s/epoch - 6ms/step
# Epoch 136/300
# 250/250 - 1s - loss: 0.0031 - mape: 22.0226 - 1s/epoch - 6ms/step
# Epoch 137/300
# 250/250 - 2s - loss: 0.0039 - mape: 40.4947 - 2s/epoch - 6ms/step
# Epoch 138/300
# 250/250 - 1s - loss: 0.0038 - mape: 35.3192 - 1s/epoch - 6ms/step
# Epoch 139/300
# 250/250 - 1s - loss: 0.0031 - mape: 49.5743 - 1s/epoch - 6ms/step
# Epoch 140/300
# 250/250 - 1s - loss: 0.0036 - mape: 85.9801 - 1s/epoch - 6ms/step
# Epoch 141/300
# 250/250 - 1s - loss: 0.0030 - mape: 38.7305 - 1s/epoch - 6ms/step
# Epoch 142/300
# 250/250 - 1s - loss: 0.0042 - mape: 49.6856 - 1s/epoch - 6ms/step
# Epoch 143/300
# 250/250 - 1s - loss: 0.0042 - mape: 40.9062 - 1s/epoch - 6ms/step
# Epoch 144/300
# 250/250 - 1s - loss: 0.0040 - mape: 34.8897 - 1s/epoch - 6ms/step
# Epoch 145/300
# 250/250 - 1s - loss: 0.0035 - mape: 31.6511 - 1s/epoch - 6ms/step
# Epoch 146/300
# 250/250 - 1s - loss: 0.0030 - mape: 26.8534 - 1s/epoch - 6ms/step
# Epoch 147/300
# 250/250 - 1s - loss: 0.0031 - mape: 22.4237 - 1s/epoch - 6ms/step
# Epoch 148/300
# 250/250 - 1s - loss: 0.0044 - mape: 58.4872 - 1s/epoch - 6ms/step
# Epoch 149/300
# 250/250 - 1s - loss: 0.0038 - mape: 53.3192 - 1s/epoch - 6ms/step
# Epoch 150/300
# 250/250 - 1s - loss: 0.0034 - mape: 76.7002 - 1s/epoch - 6ms/step
# Epoch 151/300
# 250/250 - 1s - loss: 0.0031 - mape: 36.2990 - 1s/epoch - 6ms/step
# Epoch 152/300
# 250/250 - 1s - loss: 0.0033 - mape: 66.9187 - 1s/epoch - 6ms/step
# Epoch 153/300
# 250/250 - 1s - loss: 0.0030 - mape: 40.2238 - 1s/epoch - 6ms/step
# Epoch 154/300
# 250/250 - 1s - loss: 0.0027 - mape: 82.9373 - 1s/epoch - 6ms/step
# Epoch 155/300
# 250/250 - 1s - loss: 0.0029 - mape: 32.0358 - 1s/epoch - 6ms/step
# Epoch 156/300
# 250/250 - 1s - loss: 0.0030 - mape: 67.4972 - 1s/epoch - 6ms/step
# Epoch 157/300
# 250/250 - 1s - loss: 0.0031 - mape: 45.5075 - 1s/epoch - 6ms/step
# Epoch 158/300
# 250/250 - 1s - loss: 0.0031 - mape: 43.7684 - 1s/epoch - 6ms/step
# Epoch 159/300
# 250/250 - 1s - loss: 0.0028 - mape: 21.8102 - 1s/epoch - 6ms/step
# Epoch 160/300
# 250/250 - 1s - loss: 0.0032 - mape: 65.5584 - 1s/epoch - 6ms/step
# Epoch 161/300
# 250/250 - 1s - loss: 0.0030 - mape: 22.8648 - 1s/epoch - 6ms/step
# Epoch 162/300
# 250/250 - 1s - loss: 0.0036 - mape: 64.1099 - 1s/epoch - 6ms/step
# Epoch 163/300
# 250/250 - 1s - loss: 0.0035 - mape: 27.8678 - 1s/epoch - 6ms/step
# Epoch 164/300
# 250/250 - 1s - loss: 0.0034 - mape: 26.6083 - 1s/epoch - 6ms/step
# Epoch 165/300
# 250/250 - 1s - loss: 0.0031 - mape: 27.9924 - 1s/epoch - 6ms/step
# Epoch 166/300
# 250/250 - 1s - loss: 0.0026 - mape: 24.4549 - 1s/epoch - 6ms/step
# Epoch 167/300
# 250/250 - 1s - loss: 0.0029 - mape: 49.2692 - 1s/epoch - 6ms/step
# Epoch 168/300
# 250/250 - 1s - loss: 0.0030 - mape: 50.4769 - 1s/epoch - 6ms/step
# Epoch 169/300
# 250/250 - 1s - loss: 0.0033 - mape: 43.0665 - 1s/epoch - 6ms/step
# Epoch 170/300
# 250/250 - 1s - loss: 0.0031 - mape: 50.4149 - 1s/epoch - 6ms/step
# Epoch 171/300
# 250/250 - 1s - loss: 0.0032 - mape: 84.2673 - 1s/epoch - 6ms/step
# Epoch 172/300
# 250/250 - 1s - loss: 0.0028 - mape: 22.3207 - 1s/epoch - 6ms/step
# Epoch 173/300
# 250/250 - 1s - loss: 0.0021 - mape: 33.7643 - 1s/epoch - 6ms/step
# Epoch 174/300
# 250/250 - 1s - loss: 0.0021 - mape: 29.1242 - 1s/epoch - 6ms/step
# Epoch 175/300
# 250/250 - 1s - loss: 0.0027 - mape: 18.7043 - 1s/epoch - 6ms/step
# Epoch 176/300
# 250/250 - 1s - loss: 0.0028 - mape: 27.6903 - 1s/epoch - 6ms/step
# Epoch 177/300
# 250/250 - 1s - loss: 0.0036 - mape: 57.6395 - 1s/epoch - 6ms/step
# Epoch 178/300
# 250/250 - 1s - loss: 0.0024 - mape: 41.9686 - 1s/epoch - 6ms/step
# Epoch 179/300
# 250/250 - 1s - loss: 0.0027 - mape: 33.2607 - 1s/epoch - 6ms/step
# Epoch 180/300
# 250/250 - 1s - loss: 0.0025 - mape: 73.1129 - 1s/epoch - 6ms/step
# Epoch 181/300
# 250/250 - 1s - loss: 0.0029 - mape: 51.1136 - 1s/epoch - 6ms/step
# Epoch 182/300
# 250/250 - 1s - loss: 0.0020 - mape: 55.7859 - 1s/epoch - 6ms/step
# Epoch 183/300
# 250/250 - 1s - loss: 0.0024 - mape: 30.6249 - 1s/epoch - 6ms/step
# Epoch 184/300
# 250/250 - 1s - loss: 0.0020 - mape: 21.5967 - 1s/epoch - 6ms/step
# Epoch 185/300
# 250/250 - 1s - loss: 0.0026 - mape: 89.5556 - 1s/epoch - 6ms/step
# Epoch 186/300
# 250/250 - 1s - loss: 0.0027 - mape: 63.5931 - 1s/epoch - 6ms/step
# Epoch 187/300
# 250/250 - 1s - loss: 0.0022 - mape: 20.0532 - 1s/epoch - 6ms/step
# Epoch 188/300
# 250/250 - 1s - loss: 0.0083 - mape: 70.9337 - 1s/epoch - 6ms/step
# Epoch 189/300
# 250/250 - 1s - loss: 0.0032 - mape: 51.8098 - 1s/epoch - 6ms/step
# Epoch 190/300
# 250/250 - 1s - loss: 0.0021 - mape: 40.4213 - 1s/epoch - 6ms/step
# Epoch 191/300
# 250/250 - 2s - loss: 0.0017 - mape: 35.8354 - 2s/epoch - 6ms/step
# Epoch 192/300
# 250/250 - 1s - loss: 0.0015 - mape: 30.4416 - 1s/epoch - 6ms/step
# Epoch 193/300
# 250/250 - 1s - loss: 0.0015 - mape: 19.9395 - 1s/epoch - 6ms/step
# Epoch 194/300
# 250/250 - 1s - loss: 0.0018 - mape: 26.6400 - 1s/epoch - 6ms/step
# Epoch 195/300
# 250/250 - 1s - loss: 0.0014 - mape: 20.2772 - 1s/epoch - 6ms/step
# Epoch 196/300
# 250/250 - 1s - loss: 0.0016 - mape: 21.1343 - 1s/epoch - 6ms/step
# Epoch 197/300
# 250/250 - 1s - loss: 0.0016 - mape: 35.4270 - 1s/epoch - 6ms/step
# Epoch 198/300
# 250/250 - 1s - loss: 0.0018 - mape: 46.1673 - 1s/epoch - 6ms/step
# Epoch 199/300
# 250/250 - 1s - loss: 0.0029 - mape: 37.7435 - 1s/epoch - 6ms/step
# Epoch 200/300
# 250/250 - 1s - loss: 0.0026 - mape: 52.1562 - 1s/epoch - 6ms/step
# Epoch 201/300
# 250/250 - 1s - loss: 0.0020 - mape: 28.6487 - 1s/epoch - 6ms/step
# Epoch 202/300
# 250/250 - 1s - loss: 0.0020 - mape: 22.9163 - 1s/epoch - 6ms/step
# Epoch 203/300
# 250/250 - 1s - loss: 0.0021 - mape: 17.1996 - 1s/epoch - 6ms/step
# Epoch 204/300
# 250/250 - 1s - loss: 0.0021 - mape: 43.9470 - 1s/epoch - 6ms/step
# Epoch 205/300
# 250/250 - 1s - loss: 0.0015 - mape: 15.2571 - 1s/epoch - 6ms/step
# Epoch 206/300
# 250/250 - 1s - loss: 0.0016 - mape: 22.4864 - 1s/epoch - 6ms/step
# Epoch 207/300
# 250/250 - 1s - loss: 0.0021 - mape: 55.5973 - 1s/epoch - 6ms/step
# Epoch 208/300
# 250/250 - 1s - loss: 0.0019 - mape: 24.0822 - 1s/epoch - 6ms/step
# Epoch 209/300
# 250/250 - 1s - loss: 0.0025 - mape: 63.2886 - 1s/epoch - 6ms/step
# Epoch 210/300
# 250/250 - 1s - loss: 0.0025 - mape: 52.7927 - 1s/epoch - 6ms/step
# Epoch 211/300
# 250/250 - 1s - loss: 0.0018 - mape: 36.1687 - 1s/epoch - 6ms/step
# Epoch 212/300
# 250/250 - 1s - loss: 0.0016 - mape: 23.8888 - 1s/epoch - 6ms/step
# Epoch 213/300
# 250/250 - 1s - loss: 0.0016 - mape: 29.3167 - 1s/epoch - 6ms/step
# Epoch 214/300
# 250/250 - 1s - loss: 0.0015 - mape: 35.7304 - 1s/epoch - 6ms/step
# Epoch 215/300
# 250/250 - 1s - loss: 0.0017 - mape: 47.6607 - 1s/epoch - 6ms/step
# Epoch 216/300
# 250/250 - 1s - loss: 0.0017 - mape: 43.9811 - 1s/epoch - 6ms/step
# Epoch 217/300
# 250/250 - 1s - loss: 0.0020 - mape: 41.0607 - 1s/epoch - 6ms/step
# Epoch 218/300
# 250/250 - 1s - loss: 0.0016 - mape: 21.5790 - 1s/epoch - 6ms/step
# Epoch 219/300
# 250/250 - 1s - loss: 0.0017 - mape: 39.2527 - 1s/epoch - 6ms/step
# Epoch 220/300
# 250/250 - 1s - loss: 0.0019 - mape: 34.9085 - 1s/epoch - 6ms/step
# Epoch 221/300
# 250/250 - 2s - loss: 0.0014 - mape: 25.6849 - 2s/epoch - 6ms/step
# Epoch 222/300
# 250/250 - 1s - loss: 0.0015 - mape: 55.3533 - 1s/epoch - 6ms/step
# Epoch 223/300
# 250/250 - 1s - loss: 0.0017 - mape: 19.8351 - 1s/epoch - 6ms/step
# Epoch 224/300
# 250/250 - 1s - loss: 0.0028 - mape: 120.0148 - 1s/epoch - 6ms/step
# Epoch 225/300
# 250/250 - 1s - loss: 0.0019 - mape: 28.8099 - 1s/epoch - 6ms/step
# Epoch 226/300
# 250/250 - 1s - loss: 0.0019 - mape: 29.2839 - 1s/epoch - 6ms/step
# Epoch 227/300
# 250/250 - 1s - loss: 0.0013 - mape: 13.3773 - 1s/epoch - 6ms/step
# Epoch 228/300
# 250/250 - 1s - loss: 0.0011 - mape: 21.9301 - 1s/epoch - 6ms/step
# Epoch 229/300
# 250/250 - 1s - loss: 0.0012 - mape: 45.4907 - 1s/epoch - 6ms/step
# Epoch 230/300
# 250/250 - 1s - loss: 0.0012 - mape: 29.1913 - 1s/epoch - 6ms/step
# Epoch 231/300
# 250/250 - 1s - loss: 0.0030 - mape: 33.3022 - 1s/epoch - 6ms/step
# Epoch 232/300
# 250/250 - 1s - loss: 0.0033 - mape: 54.6024 - 1s/epoch - 6ms/step
# Epoch 233/300
# 250/250 - 1s - loss: 0.0018 - mape: 21.5600 - 1s/epoch - 6ms/step
# Epoch 234/300
# 250/250 - 1s - loss: 0.0012 - mape: 19.4533 - 1s/epoch - 6ms/step
# Epoch 235/300
# 250/250 - 1s - loss: 0.0011 - mape: 23.2446 - 1s/epoch - 6ms/step
# Epoch 236/300
# 250/250 - 1s - loss: 9.7840e-04 - mape: 27.4856 - 1s/epoch - 6ms/step
# Epoch 237/300
# 250/250 - 1s - loss: 0.0011 - mape: 27.6785 - 1s/epoch - 6ms/step
# Epoch 238/300
# 250/250 - 1s - loss: 9.4292e-04 - mape: 27.5250 - 1s/epoch - 6ms/step
# Epoch 239/300
# 250/250 - 1s - loss: 9.6943e-04 - mape: 20.3444 - 1s/epoch - 6ms/step
# Epoch 240/300
# 250/250 - 1s - loss: 0.0011 - mape: 35.2310 - 1s/epoch - 6ms/step
# Epoch 241/300
# 250/250 - 1s - loss: 0.0022 - mape: 28.5056 - 1s/epoch - 6ms/step
# Epoch 242/300
# 250/250 - 1s - loss: 0.0017 - mape: 16.6364 - 1s/epoch - 6ms/step
# Epoch 243/300
# 250/250 - 1s - loss: 0.0011 - mape: 39.6404 - 1s/epoch - 6ms/step
# Epoch 244/300
# 250/250 - 1s - loss: 0.0011 - mape: 17.1317 - 1s/epoch - 6ms/step
# Epoch 245/300
# 250/250 - 1s - loss: 0.0012 - mape: 19.1550 - 1s/epoch - 6ms/step
# Epoch 246/300
# 250/250 - 1s - loss: 0.0021 - mape: 22.7701 - 1s/epoch - 6ms/step
# Epoch 247/300
# 250/250 - 1s - loss: 0.0022 - mape: 53.5489 - 1s/epoch - 6ms/step
# Epoch 248/300
# 250/250 - 1s - loss: 0.0013 - mape: 35.7486 - 1s/epoch - 6ms/step
# Epoch 249/300
# 250/250 - 1s - loss: 0.0012 - mape: 28.1764 - 1s/epoch - 6ms/step
# Epoch 250/300
# 250/250 - 1s - loss: 0.0013 - mape: 22.3469 - 1s/epoch - 6ms/step
# Epoch 251/300
# 250/250 - 1s - loss: 0.0011 - mape: 27.9498 - 1s/epoch - 6ms/step
# Epoch 252/300
# 250/250 - 1s - loss: 0.0011 - mape: 21.5805 - 1s/epoch - 6ms/step
# Epoch 253/300
# 250/250 - 1s - loss: 9.6108e-04 - mape: 12.0917 - 1s/epoch - 6ms/step
# Epoch 254/300
# 250/250 - 1s - loss: 0.0010 - mape: 14.3114 - 1s/epoch - 6ms/step
# Epoch 255/300
# 250/250 - 1s - loss: 0.0013 - mape: 48.4904 - 1s/epoch - 6ms/step
# Epoch 256/300
# 250/250 - 1s - loss: 0.0015 - mape: 40.7058 - 1s/epoch - 6ms/step
# Epoch 257/300
# 250/250 - 1s - loss: 0.0014 - mape: 20.2905 - 1s/epoch - 6ms/step
# Epoch 258/300
# 250/250 - 1s - loss: 0.0013 - mape: 27.9595 - 1s/epoch - 6ms/step
# Epoch 259/300
# 250/250 - 1s - loss: 9.2475e-04 - mape: 27.9943 - 1s/epoch - 6ms/step
# Epoch 260/300
# 250/250 - 1s - loss: 0.0011 - mape: 23.6461 - 1s/epoch - 6ms/step
# Epoch 261/300
# 250/250 - 1s - loss: 0.0016 - mape: 34.4412 - 1s/epoch - 6ms/step
# Epoch 262/300
# 250/250 - 1s - loss: 0.0011 - mape: 37.0429 - 1s/epoch - 6ms/step
# Epoch 263/300
# 250/250 - 1s - loss: 0.0012 - mape: 25.2732 - 1s/epoch - 6ms/step
# Epoch 264/300
# 250/250 - 1s - loss: 0.0011 - mape: 42.1956 - 1s/epoch - 6ms/step
# Epoch 265/300
# 250/250 - 1s - loss: 0.0010 - mape: 43.0029 - 1s/epoch - 6ms/step
# Epoch 266/300
# 250/250 - 1s - loss: 0.0014 - mape: 28.5628 - 1s/epoch - 6ms/step
# Epoch 267/300
# 250/250 - 1s - loss: 8.5864e-04 - mape: 14.2363 - 1s/epoch - 6ms/step
# Epoch 268/300
# 250/250 - 1s - loss: 8.1283e-04 - mape: 22.7285 - 1s/epoch - 6ms/step
# Epoch 269/300
# 250/250 - 1s - loss: 0.0011 - mape: 21.0709 - 1s/epoch - 6ms/step
# Epoch 270/300
# 250/250 - 1s - loss: 8.8742e-04 - mape: 19.6096 - 1s/epoch - 6ms/step
# Epoch 271/300
# 250/250 - 1s - loss: 0.0013 - mape: 21.0716 - 1s/epoch - 6ms/step
# Epoch 272/300
# 250/250 - 1s - loss: 0.0036 - mape: 35.3323 - 1s/epoch - 6ms/step
# Epoch 273/300
# 250/250 - 1s - loss: 8.8374e-04 - mape: 16.9462 - 1s/epoch - 6ms/step
# Epoch 274/300
# 250/250 - 1s - loss: 6.0755e-04 - mape: 20.1167 - 1s/epoch - 6ms/step
# Epoch 275/300
# 250/250 - 1s - loss: 7.6090e-04 - mape: 32.2115 - 1s/epoch - 6ms/step
# Epoch 276/300
# 250/250 - 1s - loss: 7.4567e-04 - mape: 38.5878 - 1s/epoch - 6ms/step
# Epoch 277/300
# 250/250 - 1s - loss: 6.8860e-04 - mape: 17.5887 - 1s/epoch - 6ms/step
# Epoch 278/300
# 250/250 - 1s - loss: 6.4609e-04 - mape: 19.8714 - 1s/epoch - 6ms/step
# Epoch 279/300
# 250/250 - 1s - loss: 9.8357e-04 - mape: 26.3781 - 1s/epoch - 6ms/step
# Epoch 280/300
# 250/250 - 1s - loss: 0.0013 - mape: 19.7456 - 1s/epoch - 6ms/step
# Epoch 281/300
# 250/250 - 1s - loss: 8.1238e-04 - mape: 14.0612 - 1s/epoch - 6ms/step
# Epoch 282/300
# 250/250 - 1s - loss: 8.5524e-04 - mape: 28.7404 - 1s/epoch - 6ms/step
# Epoch 283/300
# 250/250 - 1s - loss: 9.7623e-04 - mape: 12.1113 - 1s/epoch - 6ms/step
# Epoch 284/300
# 250/250 - 1s - loss: 8.2035e-04 - mape: 27.5772 - 1s/epoch - 6ms/step
# Epoch 285/300
# 250/250 - 1s - loss: 0.0020 - mape: 16.5472 - 1s/epoch - 6ms/step
# Epoch 286/300
# 250/250 - 1s - loss: 0.0011 - mape: 22.9429 - 1s/epoch - 6ms/step
# Epoch 287/300
# 250/250 - 1s - loss: 0.0011 - mape: 28.2146 - 1s/epoch - 6ms/step
# Epoch 288/300
# 250/250 - 1s - loss: 8.2394e-04 - mape: 11.6553 - 1s/epoch - 6ms/step
# Epoch 289/300
# 250/250 - 1s - loss: 9.3602e-04 - mape: 14.9639 - 1s/epoch - 6ms/step
# Epoch 290/300
# 250/250 - 1s - loss: 7.4246e-04 - mape: 14.8390 - 1s/epoch - 6ms/step
# Epoch 291/300
# 250/250 - 1s - loss: 0.0012 - mape: 38.5449 - 1s/epoch - 6ms/step
# Epoch 292/300
# 250/250 - 1s - loss: 8.0471e-04 - mape: 26.8683 - 1s/epoch - 6ms/step
# Epoch 293/300
# 250/250 - 1s - loss: 8.0348e-04 - mape: 20.0122 - 1s/epoch - 6ms/step
# Epoch 294/300
# 250/250 - 1s - loss: 0.0010 - mape: 18.6210 - 1s/epoch - 6ms/step
# Epoch 295/300
# 250/250 - 1s - loss: 9.3029e-04 - mape: 60.8784 - 1s/epoch - 6ms/step
# Epoch 296/300
# 250/250 - 1s - loss: 8.0580e-04 - mape: 23.8640 - 1s/epoch - 6ms/step
# Epoch 297/300
# 250/250 - 1s - loss: 5.9746e-04 - mape: 22.3102 - 1s/epoch - 6ms/step
# Epoch 298/300
# 250/250 - 1s - loss: 7.1490e-04 - mape: 31.1593 - 1s/epoch - 6ms/step
# Epoch 299/300
# 250/250 - 1s - loss: 0.0015 - mape: 39.4386 - 1s/epoch - 6ms/step
# Epoch 300/300
# 250/250 - 1s - loss: 0.0011 - mape: 28.4269 - 1s/epoch - 6ms/step
# 3/3 [==============================] - 1s 5ms/step
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\1096151906.py:65: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels([f'{int(tick) / 1000000:.1f}' for tick in plt.gca().get_yticks()])
# C:\Users\User\AppData\Local\Temp\ipykernel_6060\2761330561.py:2: RuntimeWarning: '<' not supported between instances of 'int' and 'Timestamp', sort order is undefined for incomparable objects.
#   mape = np.mean(np.abs((y - y_pred)/y))*100

# %%
evaluation_results = pd.concat([sarima_results, tbats_results, lstm_results], ignore_index=True).sort_values(by=['country', 'model'], ascending=[True, True])
display(evaluation_results)

# evaluation_results.style.hide(axis = 0).to_latex(os.path.join(tables_output_folder, "tab_000.tex"))
# Out:
#      model         country  mape         me        mae              mse  \
# 46    lstm         Austria   NaN        NaN  168577.10   47797979690.88
# 0   sarima         Austria 15.74  722536.83  722536.83  612296047190.59
# 23   tbats         Austria  4.30  133718.16  196266.40   64745070964.88
# 47    lstm         Croatia   NaN        NaN   16848.19     441207668.30
# 1   sarima         Croatia  8.84   27346.90   27959.75    1130065642.03
# 24   tbats         Croatia  5.09    1729.70   16510.30     439104619.18
# 48    lstm          Cyprus   NaN        NaN   16843.59     471039608.60
# 2   sarima          Cyprus 18.57   17835.08   26949.24    1120121620.03
# 25   tbats          Cyprus 14.39   -9513.90   23994.88     908282630.48
# 49    lstm  Czech Republic   NaN        NaN   47352.97    4202772079.26
# 3   sarima  Czech Republic  6.71   63358.34   78072.51    9257542994.44
# 26   tbats  Czech Republic  4.29   13768.99   51339.74    4837650568.24
# 50    lstm         Denmark   NaN        NaN   27559.66    1435388195.88
# 4   sarima         Denmark  7.92   50104.78   51476.62    3381341657.75
# 27   tbats         Denmark  3.84  -18315.54   26499.67    1381167624.47
# 51    lstm         Estonia   NaN        NaN    6560.75      72128211.47
# 5   sarima         Estonia 10.53  -15417.29   16485.48     410624353.90
# 28   tbats         Estonia  4.19     451.50    6679.08      81734002.35
# 52    lstm         Finland   NaN        NaN   59812.65    5884800292.38
# 6   sarima         Finland  5.63   55711.89   86065.58   12340083833.67
# 29   tbats         Finland  4.86  -12235.58   77081.75   10447325255.46
# 53    lstm          France   NaN        NaN  577673.44  607176262878.08
# 7   sarima          France 13.81 1058883.84 1107041.17 1584423586256.57
# 30   tbats          France  6.33  361904.50  534294.69  467397192944.04
# 54    lstm         Germany   NaN        NaN 1404751.87 3263722143326.70
# 8   sarima         Germany  3.61   37163.50 1336308.37 2601292630495.27
# 31   tbats         Germany  3.53  210646.94 1295239.27 2699346490877.58
# 55    lstm          Greece   NaN        NaN   74363.80    9374254624.77
# 9   sarima          Greece 16.74  146897.97  150817.03   30906750031.84
# 32   tbats          Greece  6.61   -8598.65   65642.39    7872450581.80
# 56    lstm         Hungary   NaN        NaN  149965.52   37522630052.11
# 10  sarima         Hungary  6.89  186127.61  216064.13   74564416918.01
# 33   tbats         Hungary  4.70    6920.71  151393.00   34962945917.40
# 57    lstm         Ireland   NaN        NaN   41969.22    3643318228.48
# 11  sarima         Ireland  5.16   48627.02   56765.84    4442309404.09
# 34   tbats         Ireland  3.75  -12386.96   41904.18    2847768371.96
# 58    lstm           Italy   NaN        NaN  298918.99  165755531760.70
# 12  sarima           Italy  6.12   80916.88  302084.55  180496031016.27
# 35   tbats           Italy  6.52  197060.91  319245.98  192720508659.88
# 59    lstm          Latvia   NaN        NaN    3914.11      28528722.82
# 13  sarima          Latvia  7.59  -10107.83   10368.49     157542586.55
# 36   tbats          Latvia  3.08     533.37    4236.06      33098504.59
# 60    lstm       Lithuania   NaN        NaN    9214.61     151635193.48
# 14  sarima       Lithuania  7.02   14428.86   15504.48     336768284.38
# 37   tbats       Lithuania  3.72    2689.30    8446.85     132367986.94
# 61    lstm      Luxembourg   NaN        NaN   30191.76    1461899370.21
# 15  sarima      Luxembourg  8.75   16907.50   23502.79     897511531.60
# 38   tbats      Luxembourg  9.67   18387.83   25821.10    1099005068.23
# 62    lstm          Poland   NaN        NaN  128414.93   27028872161.98
# 16  sarima          Poland  3.95   57296.13  122165.06   25673476949.67
# 39   tbats          Poland  3.86  -13716.21  122430.53   23699365990.59
# 63    lstm        Portugal   NaN        NaN   38667.94    2545850373.00
# 17  sarima        Portugal  9.70   82578.26   87098.64   10199211976.44
# 40   tbats        Portugal  5.57   40356.54   49933.15    3913242629.56
# 64    lstm         Romania   NaN        NaN   33216.89    1850164392.27
# 18  sarima         Romania  5.11   46006.62   54494.70    5133002230.50
# 41   tbats         Romania  4.08    1932.65   44622.76    3355053288.22
# 65    lstm        Slovakia   NaN        NaN   18404.19     524643391.66
# 19  sarima        Slovakia  5.09   -8557.79   27289.16    1117661405.30
# 42   tbats        Slovakia  4.43    4178.70   23163.50     815240047.73
# 66    lstm        Slovenia   NaN        NaN   12340.59     268616014.36
# 20  sarima        Slovenia  6.22   12041.66   15055.63     375200792.14
# 43   tbats        Slovenia  5.08    8428.27   12259.88     281092011.50
# 67    lstm           Spain   NaN        NaN  212991.18   86500356167.99
# 21  sarima           Spain  7.35  301947.30  324909.14  151415308947.60
# 44   tbats           Spain  5.14  182153.97  225054.71   84766018252.54
# 68    lstm          Sweden   NaN        NaN  130902.81   36638812764.77
# 22  sarima          Sweden 15.76  375131.31  378604.82  173719872964.19
# 45   tbats          Sweden  4.32    4305.71  118204.08   24005393397.89
#
#          rmse
# 46  218627.49
# 0   782493.48
# 23  254450.53
# 47   21004.94
# 1    33616.45
# 24   20954.82
# 48   21703.45
# 2    33468.22
# 25   30137.73
# 49   64828.79
# 3    96216.13
# 26   69553.22
# 50   37886.52
# 4    58149.30
# 27   37164.06
# 51    8492.83
# 5    20263.87
# 28    9040.69
# 52   76712.45
# 6   111085.93
# 29  102212.16
# 53  779215.16
# 7  1258738.89
# 30  683664.53
# 54 1806577.47
# 8  1612852.33
# 31 1642968.80
# 55   96820.73
# 9   175803.16
# 32   88726.83
# 56  193707.59
# 10  273064.86
# 33  186983.81
# 57   60359.91
# 11   66650.65
# 34   53364.49
# 58  407130.85
# 12  424848.24
# 35  438999.44
# 59    5341.23
# 13   12551.60
# 36    5753.13
# 60   12314.02
# 14   18351.25
# 37   11505.13
# 61   38234.79
# 15   29958.50
# 38   33151.25
# 62  164404.60
# 16  160229.45
# 39  153945.98
# 63   50456.42
# 17  100991.15
# 40   62555.92
# 64   43013.54
# 18   71644.97
# 41   57922.82
# 65   22905.10
# 19   33431.44
# 42   28552.41
# 66   16389.51
# 20   19370.10
# 43   16765.80
# 67  294109.43
# 21  389121.20
# 44  291146.04
# 68  191412.68
# 22  416797.16
# 45  154936.74

# %% [markdown]
# Połączone wykresy porównujące modele

# %%
# List of the models
models = ['sarima', 'tbats', 'lstm']

for country in data_for_the_model['Country'].unique():
    # List of paths to PNG files with plots for each model
    paths = [os.path.join(images_output_folder, f'{model}_predictions_{country}.png') for model in models]

    # Load PNG images
    images = [Image.open(path) for path in paths]

    # Get image dimensions
    widths, heights = zip(*(image.size for image in images))

    # Create a new image with a width equal to the widest image and a height equal to the sum of heights
    new_width = max(widths)
    new_height = sum(heights)

    new_image = Image.new('RGB', (new_width, new_height), (255, 255, 255))  # White background

    # Paste images onto the new image
    current_height = 0
    for image in images:
        new_image.paste(image, (0, current_height))
        current_height += image.size[1]

    # Save the new image
    output_file_path = os.path.join(images_output_folder, f'model_comparison_{country}.png')
    new_image.save(output_file_path)
